# %%
from stackapi import StackAPI
from bs4 import BeautifulSoup
import requests as re
from time import sleep
from random import randint
import pandas as pd
from datetime import datetime, timedelta

# %%
import os
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_id = os.environ.get("SPOTIPY_CLIENT_ID")
client_secret = os.environ.get("SPOTIPY_CLIENT_SECRET")

sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

# %% [markdown]
# #### Find top song per genre

# %% [markdown]
# **!** Spotify doesn't expose genres for tracks, the closest you can get is to check the genre of the album the track is on. Genre is however only part of the full album object, and not the simple album object. To get the album's genre, first requesting the Track metadata to get the album URI, and continue to request Album metadata. You can also get an artist's genres by calling the Artist metadata endpoint.

# %%
sp.recommendation_genre_seeds()
# Out:
# {'genres': ['acoustic',
#   'afrobeat',
#   'alt-rock',
#   'alternative',
#   'ambient',
#   'anime',
#   'black-metal',
#   'bluegrass',
#   'blues',
#   'bossanova',
#   'brazil',
#   'breakbeat',
#   'british',
#   'cantopop',
#   'chicago-house',
#   'children',
#   'chill',
#   'classical',
#   'club',
#   'comedy',
#   'country',
#   'dance',
#   'dancehall',
#   'death-metal',
#   'deep-house',
#   'detroit-techno',
#   'disco',
#   'disney',
#   'drum-and-bass',
#   'dub',
#   'dubstep',
#   'edm',
#   'electro',
#   'electronic',
#   'emo',
#   'folk',
#   'forro',
#   'french',
#   'funk',
#   'garage',
#   'german',
#   'gospel',
#   'goth',
#   'grindcore',
#   'groove',
#   'grunge',
#   'guitar',
#   'happy',
#   'hard-rock',
#   'hardcore',
#   'hardstyle',
#   'heavy-metal',
#   'hip-hop',
#   'holidays',
#   'honky-tonk',
#   'house',
#   'idm',
#   'indian',
#   'indie',
#   'indie-pop',
#   'industrial',
#   'iranian',
#   'j-dance',
#   'j-idol',
#   'j-pop',
#   'j-rock',
#   'jazz',
#   'k-pop',
#   'kids',
#   'latin',
#   'latino',
#   'malay',
#   'mandopop',
#   'metal',
#   'metal-misc',
#   'metalcore',
#   'minimal-techno',
#   'movies',
#   'mpb',
#   'new-age',
#   'new-release',
#   'opera',
#   'pagode',
#   'party',
#   'philippines-opm',
#   'piano',
#   'pop',
#   'pop-film',
#   'post-dubstep',
#   'power-pop',
#   'progressive-house',
#   'psych-rock',
#   'punk',
#   'punk-rock',
#   'r-n-b',
#   'rainy-day',
#   'reggae',
#   'reggaeton',
#   'road-trip',
#   'rock',
#   'rock-n-roll',
#   'rockabilly',
#   'romance',
#   'sad',
#   'salsa',
#   'samba',
#   'sertanejo',
#   'show-tunes',
#   'singer-songwriter',
#   'ska',
#   'sleep',
#   'songwriter',
#   'soul',
#   'soundtracks',
#   'spanish',
#   'study',
#   'summer',
#   'swedish',
#   'synth-pop',
#   'tango',
#   'techno',
#   'trance',
#   'trip-hop',
#   'turkish',
#   'work-out',
#   'world-music']}

# %% [markdown]
# #### Selected genres :
# * blues
# * classical
# * country
# * electro
# * funk
# * hip-hop
# * j-pop
# * latino
# * metal
# * pop
# * punk
# * reggae
# * rock

# %%
# loop this list throught the sp.recommendations()
# extract albums IDs from the reco
# extact tracks IDs from albums
# reaveal audio_features from tracks
# bin them according to audio_features

# %% [markdown]
# ###

# %% [markdown]
# ___________

# %% [markdown]
# ## SONG FEATURES EXTRACT INTO DATAFRAME (prototype)

# %%
genres = ['blues','classical','country','electro','funk','hip-hop','j-pop','latino','metal','pop','punk','reggae','rock']

# %% [markdown]
# ### Extract album ID according to genre

# %%
genres = ['blues','classical','country','electro','funk','hip-hop','j-pop','latino','metal','pop','punk','reggae','rock']
result = []
ids = []

def reco_loop(x):
    for item in x:
        result.append(sp.recommendations(seed_genres = [item]))
    for el in range(0,len(result)):
        ids.append(result[el]['tracks'][0]['album']['id'])
    return ids

# %%
reco_albums_2 = reco_loop(genres)

# %%
reco_albums_2
# Out:
# ['6buMKDijbVSYjvO0BU0gMN',
#  '62X0Jj0lhqRQOS6LYii82Q',
#  '6YXkbmsVABrzPBO6Vknj2P',
#  '1YhwGzFBdDAR1OA9644LK9',
#  '0Ly7HZvko6HkBrdG0a7eQs',
#  '3e7vtKJ3m1zVh38VGq2g3H',
#  '0bMDgeX80YZkTMpZG5oM6E',
#  '5GZMllVH8wRfhwyfVNu7cv',
#  '0G3YLIcJdk5wqqLAgOCmL8',
#  '0CoiTAUBiO70lic9p9Lboq',
#  '3kuplU3nbDAVTW6P8SRZwP',
#  '5DVnbxc2ApzkGnQaMRbv0z',
#  '0iIGP4Sxw3KR4OCFv2yvz8']

# %% [markdown]
# ### From returned album ids, extract all track Ids

# %%
def get_track_ids_from_albums(album_ids):
    return list(set([i["id"] for j in album_ids for i in sp.album(j)["tracks"]["items"]]))

# %%
tracks_id_2 = get_track_ids_from_albums(reco_albums_2)

# %%
# list of track IDs
tracks_id_2
# Out:
# ['4ce29VAx1D8f3HULOHHA3K',
#  '4CQAXfHKDi11d2xaeX0591',
#  '5qifWYBY62MNvk42U8UkDC',
#  '2T8AHOmg9Di867U930oQNu',
#  '2l6ZiDwuSo8SPPz2LviWjt',
#  '23mkKDVw5XAX48KCKEq3Ru',
#  '3UyZtf5BzjEYFJkIiIipoH',
#  '2W9bSe8J7kU3DBRzhK2Pml',
#  '0vf0qLNVNoPry0cvtyOupW',
#  '3yM8iyra4fkuyf0H5RFHuE',
#  '6qYAEFZJqgDK3yhMn3FuOZ',
#  '3aDr0qgtVD6nBOvZQNwPcp',
#  '1IKiLR3P0rK4i4diaKuFNd',
#  '2kmpyKQjVw5UOcVlmkxnYY',
#  '1nICrSEk0Pl00J5cGbprLA',
#  '7kKEXvq4NQ9OatQs906MGV',
#  '346C7NrHGNsW66B5ob4u0P',
#  '0FTS9kk8zgWF1MifAUM88i',
#  '21RTmEHRU4jiD16jRWtOnf',
#  '0Sxs6lEQ9FuE9i02bfh2z3',
#  '7n1QCxOHj8w3LP1i59qFtb',
#  '5PntSbMHC1ud6Vvl8x56qd',
#  '1I14HJ4IGnFJeCvcdynaAL',
#  '6OFlkkM8gHjZjuomjrdKHv',
#  '5mxB9F2XIX7OiCAHCXLdD1',
#  '3FOldYXOvpRR0WtEJstZZm',
#  '0x9UJY5wjRPpr2yX7lZFBs',
#  '6iWbJdNf6Fl9y298RDZfrc',
#  '0wP7LI2HjLP1uuGhKetDkd',
#  '4Eh2LpK2I86jhh4wdEkout',
#  '6qpaTfe6rCl55xEPT4F7Hp',
#  '2DGbSEkVncvcUJzFYN0V9y',
#  '6fpGop5og9FIoOaZieJGUa',
#  '3b02OTLptmiqASGWBUuET9',
#  '2F6OXc011tEW3PqT7atBx3',
#  '0IMp39pja4z6Eg9BEkyZxy',
#  '42QGnH9uUswiHWXewIkON9',
#  '0oy3PntYJjTfSVqtRfqozE',
#  '2iP9AtOmYspGqmLjVwHejR',
#  '2pwJA5Vz3LCmTurcpLz5uT',
#  '3Rlhg35xN9yDnvNaj9F6g1',
#  '6l2Q1Jb5c2VycqDEzp5ZlJ',
#  '02EuFdrKAANJXUwTidasl0',
#  '0QHY6piYSmcoUBY44wa5hH',
#  '4kb6pH28RIiSSVd2kfS1S0',
#  '2cChJloy9itsRxeWU5WYtL',
#  '1Nd55yzmLf7co92bp8ZHpD',
#  '6nG8bZu71EdcHde5TFeiR6',
#  '5gB2fgu5bHVqLBFsh965mD',
#  '5FzEeRc1LskfW3TUdGgRuC',
#  '56ifiBYUXWXB5Lk3nWfTyq',
#  '6iMo7yzmXqMC57FOHOSotz',
#  '3fqfuK6PQITWU0fCKfo31d',
#  '70EDibC4MAbHf8mEq8LxNb',
#  '2k7ysbG2zy03fCZOax5HjJ',
#  '5uhHGX3Hue00d6JLBtwP2O',
#  '5ufn9s4EXZ30pFhh23zemk',
#  '5KRczDYQNxmZqydifjt8wF',
#  '3FiEa2pVN5MzEA2wrtKIsv',
#  '7ItFoQDmQIh3MAPsxiP6Vt',
#  '77JR5wTKu2cEDnD95CnWAa',
#  '1d15Mc6bkiQYS4pWJs66Hr',
#  '6vcZrdG9vCzYI6WwBXb1Nj',
#  '2TP97CWh2AjapZ56YL7anq',
#  '0zPrXk93dAfm414FMKr4TZ',
#  '5L1vbLpMx0EZlMDoMykO1Q',
#  '6iBzUjscIAeQ2vKV67UuZM',
#  '2KXxwkI93Fgq9AHoGIUCxY',
#  '1cHy9YSifVPBV0LeX6N1GV',
#  '6iM7z9ujABzcJCCpqkpCtS',
#  '7kTxncRUYhC8PC1v70moeN',
#  '6Z2TsAp4j74Q9iengNIopM',
#  '1dcoLxTLudBZYJkoLgT0hP',
#  '4DXdQGLlY6pA6JjYDxFerT',
#  '5y7aZPpx9jF38JQz3iXrQc',
#  '28rowO8tcshx1B6qygvcTv',
#  '4rlVYh39BI2FEcH50sSY3Z',
#  '1DEfUZtuT68LpLtilo4WpY',
#  '5uKsIijGkAbWmYAEdnCPhG',
#  '6zUxqwGCKrGpuSCbBury2D',
#  '4BhQPUU3wsJSlrAzTeuPTF',
#  '1XZmsm2bMlxQFiZC7AYTHb',
#  '21Q5rh3uepCh0T9cphDxiI',
#  '1LDeuD3jbSpHucsd0nOt6t',
#  '2sXlPQBvbqfaiPYB5O180o',
#  '76vMpRe5VNmiqKQ81dDR0c',
#  '3hKVeTvmtSeacbpW0N5xZe',
#  '0L35zlAe0v3eAXfV7CJKf1',
#  '01A2LnkNCPKZ8h6zoVIQju',
#  '7q6jrSUpdukGfRueBs0vNV',
#  '1IIWODSnr5MIIwpdHyX10P',
#  '7llC9IpbN9XxKyYldVDygf',
#  '5Lyv6kW8wWxjRPFuFN4EsW',
#  '77AB0zqvso8ALKUZ2HG2mG',
#  '1Y0wA6SMChTTHNS48eYJrE',
#  '3le3bMqOFAOFZjEA6Sft24',
#  '2G2dH62tGYBIQ80hEvBUGZ',
#  '31qgVdvSqTQ7unwQQngycB',
#  '2ooxstoQoE78QQQHS4COIE',
#  '5UdT2WHEhSjjH5ZWEyIdto',
#  '1THgEf7LF26w1uZmK15vXX',
#  '0GF7jlDU0lpoHOyY8A6Eva',
#  '70Xa3hqD1Vmg3qNxn9w8fC',
#  '2jypYoBC2yuuR9wtN6PzRY',
#  '30Km3dBkSA1wwq9VWIyRG4',
#  '7hfCz40h1vqxRpKwIrBlVz',
#  '2s00EsUGEVQb9P7Cwshxej',
#  '3QvZoPL2TvkoJJk8hq1e3V',
#  '2NiosP8uiwa0g7OCFLDwcR',
#  '281Bg1rYpaFuDLrMZ9EpqL',
#  '5YDFC3MTl7CE5Ca1t0HCiF',
#  '3TKt9EoDMmKvNYpk1e6GkI',
#  '3WWw0TnNdplVi2Kg2YMnQm',
#  '1uCbTCMwKzv66uhZCBvWqo',
#  '2KjchWrmSYibVzcULsA6t3',
#  '4Hg2p5WhkmqAPASAGaZ7YA',
#  '0HzyIpyjA7YQdfDiRFohW5',
#  '4lQAJfkFDE6maXDBQBJEEk',
#  '7d43nWhF5ChLqVINY8FazB',
#  '5dNTgejzqUITrZUy08EnaO',
#  '51uxYZ9WEVtTFwAfvw0E5J',
#  '1LUyHPbfI0EXbMkvHR0PNX',
#  '2J2GPBGZX3PYTDolrAdlpK',
#  '1SJfRWxxRaYISR3GK2kxoX',
#  '2bQZXTZ8mMqz6J7vU4pwh1',
#  '1O7b1wC9TOH9dIR6lrnDuJ',
#  '5E0ksdOzJS4WADfQw3b9u3',
#  '3ebrniHtOzNWigJhEkWguR',
#  '3tgKFCesTjSbeptKo5APNP',
#  '3uPLRT7eFWg4qs0TTtqKn7',
#  '0KzoBgOrDoBRl1AZIOyIP3',
#  '0v7xSr4PXLNsHUOadF1bWq',
#  '0R2JtffoFJPS8aXN0EWfHG',
#  '41ehrziGwbWT1Bl1hdqJYs',
#  '3AYcyxEACnmE6d96RPubID',
#  '4T9rk1mPdPUuoHqk6sjvcx',
#  '4Vn7ZPWD2NrXy2o3sJjAbZ',
#  '5oLyUnHXzkgBzcEr73hiaC',
#  '0lNqq59xKZKh5LreNHmqIl',
#  '6lyLexxns1OGRw3ZLOcVFC',
#  '3vSYtjnjnNeAFCnsr0IW9k',
#  '59DxvS7QLSEf1qg7FfRIn1',
#  '6LohFs1SEFD5AVYmJxqn17',
#  '2fmW1y0XfSr7eqQJ4AWAbG',
#  '6dHatCnuOb1TdBIeJTK3Y0',
#  '5gxQp5HPg7l5U8SNibeiF6',
#  '3WFUIkJyTulgixxMC2Qrjn',
#  '2KBA5YhBtkBlnnlYKrHwgy',
#  '2LAjmTgq6qaN6q4SdXZIR4',
#  '6mVTzTKVhMkVM5QeYGHjCM']

# %% [markdown]
# ### Extract audio features from returned track id list

# %%
audio_feat_2 = sp.audio_features(tracks_id_1[:100])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 audio_feat_2 = sp.audio_features(tracks_id_1)
#
# NameError: name 'sp' is not defined

# %%
# list, with embedded dictionary as items
len(audio_feat_2)
# Out:
# 100

# %% [markdown]
# ### Creating dataframe from returned audiofeatures

# %%
df2=pd.DataFrame(audio_feat_2)

df2=df2[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df2
# Out:
#     danceability  energy  loudness  speechiness  acousticness
# 0          0.755   0.889    -2.587       0.0627      0.001880  \
# 1          0.524   0.464    -5.890       0.2300      0.071400
# 2          0.608   0.585    -6.814       0.0387      0.288000
# 3          0.847   0.573   -10.018       0.0526      0.000859
# 4          0.513   0.943    -3.982       0.0619      0.000071
# ..           ...     ...       ...          ...           ...
# 95         0.546   0.603   -13.900       0.0752      0.531000
# 96         0.550   0.224   -15.423       0.3220      0.736000
# 97         0.634   0.927    -4.468       0.0838      0.027000
# 98         0.519   0.686   -13.849       0.0511      0.361000
# 99         0.588   0.632    -9.026       0.2750      0.033900
#
#     instrumentalness  liveness  valence    tempo                      id
# 0           0.863000    0.0470    0.186  127.999  4ce29VAx1D8f3HULOHHA3K  \
# 1           0.000001    0.0432    0.859   78.330  4CQAXfHKDi11d2xaeX0591
# 2           0.000302    0.0659    0.730  104.783  5qifWYBY62MNvk42U8UkDC
# 3           0.000129    0.1520    0.823  135.008  2T8AHOmg9Di867U930oQNu
# 4           0.000004    0.1640    0.528  116.999  2l6ZiDwuSo8SPPz2LviWjt
# ..               ...       ...      ...      ...                     ...
# 95          0.219000    0.1580    0.793  123.742  3le3bMqOFAOFZjEA6Sft24
# 96          0.233000    0.2310    0.310  175.932  2G2dH62tGYBIQ80hEvBUGZ
# 97          0.000000    0.0986    0.880  146.094  31qgVdvSqTQ7unwQQngycB
# 98          0.502000    0.3460    0.623  109.946  2ooxstoQoE78QQQHS4COIE
# 99          0.009360    0.1150    0.444  145.979  5UdT2WHEhSjjH5ZWEyIdto
#
#     duration_ms
# 0        315140
# 1        221600
# 2        399040
# 3        252933
# 4        224600
# ..          ...
# 95       203933
# 96       214973
# 97       258432
# 98       295133
# 99       257856
#
# [100 rows x 11 columns]

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2.describe()
# Out:
#        danceability      energy   loudness  speechiness  acousticness
# count    100.000000  100.000000  100.00000   100.000000    100.000000  \
# mean       0.567340    0.678673   -8.23645     0.113354      0.266052
# std        0.166591    0.218957    4.17755     0.098622      0.271854
# min        0.159000    0.031300  -25.07600     0.024800      0.000003
# 25%        0.474500    0.525500   -9.61625     0.043225      0.012875
# 50%        0.557000    0.684000   -7.48800     0.074400      0.180500
# 75%        0.702250    0.874750   -5.65650     0.148000      0.469250
# max        0.911000    0.990000   -2.40800     0.438000      0.957000
#
#        instrumentalness    liveness     valence       tempo    duration_ms
# count        100.000000  100.000000  100.000000  100.000000     100.000000
# mean           0.106686    0.261052    0.512052  118.822310  247240.290000
# std            0.235868    0.242672    0.271723   29.795281   93627.949742
# min            0.000000    0.042200    0.035100   67.037000  104253.000000
# 25%            0.000000    0.106000    0.280750   98.070750  198306.750000
# 50%            0.000206    0.154000    0.528000  116.963500  228208.500000
# 75%            0.020450    0.347750    0.736750  138.500000  263742.750000
# max            0.966000    0.996000    0.991000  200.937000  779933.000000
