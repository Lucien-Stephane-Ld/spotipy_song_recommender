# %%
from stackapi import StackAPI
from bs4 import BeautifulSoup
import requests as re

from time import sleep
from random import randint
import pandas as pd

from datetime import datetime, timedelta

# %%
import os
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_id = os.environ.get("SPOTIPY_CLIENT_ID")
client_secret = os.environ.get("SPOTIPY_CLIENT_SECRET")

sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

# %% [markdown]
# #### Find top song per genre

# %% [markdown]
# **!** Spotify doesn't expose genres for tracks, the closest you can get is to check the genre of the album the track is on. Genre is however only part of the full album object, and not the simple album object. To get the album's genre, first requesting the Track metadata to get the album URI, and continue to request Album metadata. You can also get an artist's genres by calling the Artist metadata endpoint.

# %%
sp.recommendation_genre_seeds()
# Out:
# {'genres': ['acoustic',
#   'afrobeat',
#   'alt-rock',
#   'alternative',
#   'ambient',
#   'anime',
#   'black-metal',
#   'bluegrass',
#   'blues',
#   'bossanova',
#   'brazil',
#   'breakbeat',
#   'british',
#   'cantopop',
#   'chicago-house',
#   'children',
#   'chill',
#   'classical',
#   'club',
#   'comedy',
#   'country',
#   'dance',
#   'dancehall',
#   'death-metal',
#   'deep-house',
#   'detroit-techno',
#   'disco',
#   'disney',
#   'drum-and-bass',
#   'dub',
#   'dubstep',
#   'edm',
#   'electro',
#   'electronic',
#   'emo',
#   'folk',
#   'forro',
#   'french',
#   'funk',
#   'garage',
#   'german',
#   'gospel',
#   'goth',
#   'grindcore',
#   'groove',
#   'grunge',
#   'guitar',
#   'happy',
#   'hard-rock',
#   'hardcore',
#   'hardstyle',
#   'heavy-metal',
#   'hip-hop',
#   'holidays',
#   'honky-tonk',
#   'house',
#   'idm',
#   'indian',
#   'indie',
#   'indie-pop',
#   'industrial',
#   'iranian',
#   'j-dance',
#   'j-idol',
#   'j-pop',
#   'j-rock',
#   'jazz',
#   'k-pop',
#   'kids',
#   'latin',
#   'latino',
#   'malay',
#   'mandopop',
#   'metal',
#   'metal-misc',
#   'metalcore',
#   'minimal-techno',
#   'movies',
#   'mpb',
#   'new-age',
#   'new-release',
#   'opera',
#   'pagode',
#   'party',
#   'philippines-opm',
#   'piano',
#   'pop',
#   'pop-film',
#   'post-dubstep',
#   'power-pop',
#   'progressive-house',
#   'psych-rock',
#   'punk',
#   'punk-rock',
#   'r-n-b',
#   'rainy-day',
#   'reggae',
#   'reggaeton',
#   'road-trip',
#   'rock',
#   'rock-n-roll',
#   'rockabilly',
#   'romance',
#   'sad',
#   'salsa',
#   'samba',
#   'sertanejo',
#   'show-tunes',
#   'singer-songwriter',
#   'ska',
#   'sleep',
#   'songwriter',
#   'soul',
#   'soundtracks',
#   'spanish',
#   'study',
#   'summer',
#   'swedish',
#   'synth-pop',
#   'tango',
#   'techno',
#   'trance',
#   'trip-hop',
#   'turkish',
#   'work-out',
#   'world-music']}

# %% [markdown]
# #### Selected genres :
# * blues
# * classical
# * country
# * electro
# * funk
# * hip-hop
# * j-pop
# * latino
# * metal
# * pop
# * punk
# * reggae
# * rock

# %%
# loop this list throught the sp.recommendations()
# extract albums IDs from the reco
# extact tracks IDs from albums
# reaveal audio_features from tracks
# bin them according to audio_features

# %%
genres = ['blues','classical','country','electro','funk','hip-hop','j-pop','latino','metal','pop','punk','reggae','rock']
result = []
ids = []

def reco_loop(x):
    for item in x:
        result.append(sp.recommendations(seed_genres = [item]))
    for el in range(0,len(result)):
        ids.append(result[el]['tracks'][0]['album']['id'])
    return ids

# %%
# Returns Album ID from first element of each JSON from each genre.
album_ids = reco_loop(genres)

# %%
len(album_ids)
# Out:
# 13

# %%
# extract songs from a given album

def get_track_ids_from_albums(x):
    return list(set([i["id"] for j in x for i in sp.album(j)["tracks"]["items"]]))

# %%
get_track_ids_from_albums(album_ids)
# Out:
# ['043bfUkTydw0xJ5JjOT91w',
#  '4CzAoTWyqgNr9gMUAmxErL',
#  '39BuMwNtaqTvsV6w7p3fd7',
#  '1jD0UV5C9pEpZwekE9ISNd',
#  '3qJgFnWloYlMzenje2aFDO',
#  '616KutkNyC9vF62z68dHKD',
#  '6xFpkmab7tBGKb4h5Qgz7w',
#  '0PNqff1BvynHvbjJh9EFUn',
#  '0eI6ZqRRptrbU8SOpjKK0o',
#  '3imvdBoQCSAoEW3yBdsHPW',
#  '1Obmd6v3lqxQAN0BlFsQP6',
#  '6a65rdAgYVcdkEQpDTZVbQ',
#  '05yG4sqzUNGbwfxsn38lQ6',
#  '3hZm2MqVqCLDoxGblUSvxj',
#  '232nQnyelarnhjBOB6JSJd',
#  '3odGV4IZGLjQW1A5Ku6kFY',
#  '54bRt4iSfEogQqRBC1tsxR',
#  '3zlWh22Bgtrmq3Cdpu7NP4',
#  '4lQmlv6BjofgYp0BjC6hBq',
#  '6T3ABqVRx45UYjlKlUcuyA',
#  '4KqOYNpmqcsptsEliWnCJE',
#  '3UjitKTcHn7vqjJPyUFHS6',
#  '7eXZZ9nxSZspusps6JMkOb',
#  '7gMktPlL90wAuKpVBhDVqr',
#  '3sNLvBdHmTBbKtFrnL2oZZ',
#  '7hTINtDW5V8tWMJvi4HH7v',
#  '4ILP355DpFaXUW4FFpPBgp',
#  '2U1bDJAym3cdNe6hhPonDJ',
#  '6Z9FNZ414aQrT7k5zSTIKY',
#  '0B7wvvmu9EISAwZnOpjhNI',
#  '0UeVZduSzYfzae5xLRPh5D',
#  '2IUatk9mnLpLuv1pz44Dei',
#  '3kGbRQCTxgMzbqVi5RHy4I',
#  '4GGrix8iZHggVP0jI4z2Gv',
#  '6lhm2rM4x0CJHyOIM1y4v2',
#  '7t5YHo3HI3NlYfatTZHMLv',
#  '0gyxF0s0Xgx1SBvxqrwC5O',
#  '2w2GduKshRATrsoGJ3MZuc',
#  '1CfKqs2jiYZOEE6DqocCSq',
#  '4uTnS5Ui4wJggpL7O8nxuC',
#  '3zNkeaT28Ak8Nxpxobbe0U',
#  '10ecRefebwLxbnVl8DWV2S',
#  '3Ip8a9C4e1XNqL5JFWrA0O',
#  '1GwmXs6kUto9OTmIKkKrVS',
#  '0iyEZbEyEMp4YhikiRA8c0',
#  '5X6NRL5XnLaf7KGbODA4P9',
#  '401e8Th4LDnIFyyQoYWyja',
#  '12srbmjUzfHjZMd8OgfCUu',
#  '11EZ9WJIQW7H37zPO2KXgf',
#  '3BbtadRvDxHuHYHMCcwvRx',
#  '5m2L40jDeGNdy3P6PRAA1c',
#  '4TxLGLypTr0Qg0ze2MBXB9',
#  '2rX49GQVKepQpjHJLBMfvE',
#  '6dlEWrN4zKC8jyO9KITpKu',
#  '0J6mQxEZnlRt9ymzFntA6z',
#  '1zIEwDU2IZyHjy17ssOvyr',
#  '3KGbsTzWwiRI91CUUc6woU',
#  '6rqVJeDMVYfWEQoZJIFOqi',
#  '0kDebmaqWn2vUtJPwegWfP',
#  '7G5cJkGKRHNP5EoEyFolkZ',
#  '5Y8cOWumrTtXU9v4dalLRc',
#  '5Ds89NFqIYSyoUOwWfZ1Ua',
#  '31HUl7TszgVZeHrtCIvyB7',
#  '5zHgYHO5WWz5Nme7Js1HEp',
#  '6rAIveezTKbwvjwVNrV1bf',
#  '0JXLAImibeNEoBMZKywrGI',
#  '2TrNXQBxFEv7xqeOaJwPyS',
#  '7edZO40XkVIPbdvd2gCHZ3',
#  '0158TMiGmHyibaDeaUKayX',
#  '6ym5mysjGMujM1evgCOBcE',
#  '381R8ZOnnrXA4IByb7U9tQ',
#  '1QBzloQxh6tW9BPkE7rJOW',
#  '7FOomGddxLBUmogfeGXCTg',
#  '4KpNcAqWaoEsdgwGGF6TJI',
#  '2LY4fPsZNni2PA9Ne0BXM7',
#  '1Rx2J5o7712moCl3kqgkHm',
#  '47jkSOZX6hFbTQoFgCKAQE',
#  '6HJK8ClN3nRBWkY9c2eDWp',
#  '3IvFVv3po52uqSjZuDOPRl',
#  '0kRlvjTfSbjCxIqMdi0v5O',
#  '1lK6KCfD8TGnTIPLzZ6xjc',
#  '4AsspdUMxLgji9Xl9ZWtJ6',
#  '5EJcVJZBl6HTfSf6z4dC78',
#  '2HKkbbCwRRXu5COx9AY5LZ',
#  '3NO2lTydHZdfNg2sElzybs',
#  '5J8m6w5VmswbMBYUAFf44t',
#  '3pAR9VRg6MdGVRo0vM5PoF',
#  '5g7sDjBhZ4I3gcFIpkrLuI',
#  '0HF0xkprbWwtn8DmaDCVK5',
#  '58m6m4xwdRgOy1mxH9J1fl',
#  '0dcd8ggtw9qcSMltSx77Cd',
#  '3KYiA4vq6RPO1dE2XROXd8',
#  '5FFUFqmEUwsFk6FCdl6MR1',
#  '1kkqMaEf5IiCHoDLEd0LJ5',
#  '5lfS4994C6ym1ouiDK8Rry',
#  '2fY6tqgrlrg1ky9fgs0t5u',
#  '1GkyqB815FNyiUn6bkDlvt',
#  '3Jc0sMBATPISEOdOweklDr',
#  '1VvOD6Vhshi5kfXQMpp6xp',
#  '7FWlUCCG85PGjZksqLjkTn',
#  '4G2Hbfwvn3oH7LxxPXjjGn',
#  '34imsMaFw19HXkJLULHT9H',
#  '21ofxkjuZJ02KiUiVQO5Jj',
#  '3F1OFAb6AKuyvERl4VAJzq',
#  '3zQ4t4cmfM6DuP0j79POrV',
#  '6K89DOnRwTZIOjnFZwJT3w',
#  '14epucTZd8dLIYipdByNZS',
#  '31UbcTZvI66s3UhfuEiNEU',
#  '4LwbL2wxtRP4yEGmvunKCM',
#  '6xmiQPeG9WUw69RLbJr2ox',
#  '0VffaI2jwQknRrxpECYHsF',
#  '4va19feyIBsuYOW6OEiuk5',
#  '3SHrwFgsvQEP04Eoo7jMB5',
#  '6rDaCGqcQB1urhpCrrD599',
#  '7aD3lqfdAtCLSyzcQ5DVQr',
#  '2TZ0BlkBcBKOIQAljtkuyS',
#  '2YQ2CCPY2QOD9Mylgnrgnk',
#  '0u2Kv2z0SyYb2rggvrlZ0D',
#  '6EVWibaVfohgErUQxUIGjM']

# %% [markdown]
# ###

# %% [markdown]
# ___________

# %% [markdown]
# ## SONG FEATURES EXTRACT INTO DATAFRAME (prototype)

# %%
genres = ['blues','classical','country','electro','funk','hip-hop','j-pop','latino','metal','pop','punk','reggae','rock']

# %% [markdown]
# ### Extract album ID according to genre

# %%
genres = ['blues','classical','country','electro','funk','hip-hop','j-pop','latino','metal','pop','punk','reggae','rock']
result = []
ids = []

def reco_loop(x):
    for item in x:
        result.append(sp.recommendations(seed_genres = [item]))
    for el in range(0,len(result)):
        ids.append(result[el]['tracks'][0]['album']['id'])
    return ids

# %%
reco_albums_1 = reco_loop(genres)

# %%
reco_albums_1
# Out:
# ['2COvDjzoJTRf7Nliwcygz7',
#  '1PZ9DdMSoEOUtvCdkQYKH3',
#  '0Ap0drTLnlqwYl4sTm6HMw',
#  '2vGSzZEJuaZVCyF23PthAD',
#  '5oQClEU6YXiVoaz4ZTmOOO',
#  '5s0rmjP8XOPhP6HhqOhuyC',
#  '5eqcQe8v8zH3T9T2OIqy8o',
#  '3mCZPmix70kS3uC4aOXz7w',
#  '5r4qa5AIQUVypFRXQzjaiu',
#  '6f6tko6NWoH00cyFOl4VYQ',
#  '176MKJ0iohkvOacfpeCfTQ',
#  '4JSutlY20GoHCSeJl0p4qJ',
#  '3Jr1RhAyndBxtyi8rJs3Op']

# %% [markdown]
# ### From returned album ids, extract all track Ids

# %%
def get_track_ids_from_albums(album_ids):
    return list(set([i["id"] for j in album_ids for i in sp.album(j)["tracks"]["items"]]))

# %%
tracks_id_1 = get_track_ids_from_albums(reco_albums_1)

# %%
# list of track IDs
tracks_id_1
# Out:
# ['18p0zFMIvihb3iA8xAYgGH',
#  '7MTIDmToGs0I5Oue9V0CHl',
#  '1QVsmXvya0zH19OsV9uEvW',
#  '5ZWkiOzFnu0p9Uzss1U0yh',
#  '2jm4r2LruBBzaEM1Q3rNOg',
#  '10XauCvE5sqohVPfzBlrEZ',
#  '46HXDYn0EmLq8vWRu4H9Jp',
#  '4Hn5LC96zhdrCyRSrTeVP7',
#  '5yuShbu70mtHXY0yLzCQLQ',
#  '7bd0BC9RNR6GxJsM3pRwBw',
#  '5IWlml6ny25ggdP4uH6xLP',
#  '7ffE3UYWppPyCRTfIrA3nf',
#  '5fG7ELU6m0pXeUc7bQUeiQ',
#  '2bAsXCjOPlRLJQMU6luhAq',
#  '6dHAJi8G7DSlNTdWZdwugw',
#  '3dM6eswFwcH5Smmm75b3aQ',
#  '28S2K2KIvnZ9H6AyhRtenm',
#  '02opp1cycqiFNDpLd2o1J3',
#  '55LmWlUjASU4zHUF81DVqN',
#  '75ZvA4QfFiZvzhj2xkaWAh',
#  '0IWIYbXZA4viXygWl8Us41',
#  '363CvSAEizy3j1Mca3mVLs',
#  '0GTWn2GTjeHZ7Q8oub6srI',
#  '5wEbVkDzMqWmprdR4WN0wU',
#  '3Tg6oJPC53D5bvUzi44Gg8',
#  '1OubIZ0ARYCUq5kceYUQiO',
#  '39bighg4X08plAXXt9dC7T',
#  '3XsM6HwxpN1qVc9R8XS8ju',
#  '2nElnhRIWeYrz8zHbger0C',
#  '4R5kwDx0ryIMiK2PKqbNVY',
#  '06wBxj4nIpnZI9dKWfGu4o',
#  '73as6nDlbfxHMot61IbQoK',
#  '7zuAY2PjlvZ0GU5hfAsY6T',
#  '5dKl1tHgvRWYObC3uM6J0P',
#  '54nkY5drz9k6z7M5EfbUqc',
#  '78snvlY005Y8L67EmTrjpE',
#  '0sYsjuh80y8Ty1CS6F60b2',
#  '3EV3O1BXb5iEvwdSLWdfGU',
#  '0QRxtcxL31dRAeiUUuENPu',
#  '6pyeRIfBf6xQaptPWaqmmX',
#  '21AyD8apDt1b8ozJJ3Fswg',
#  '2U3B9VLLo3XgZDtvUHbA4V',
#  '6Ws3GKNOMs5hkGzhY9adlj',
#  '6kHFFUgDXeJhX0jcif2op1',
#  '5rJgABn4j6vt97eP8YH8ML',
#  '1FXE1CMtph4zhOr1MywGdJ',
#  '1FEguBjPAhX5Go3nJQVrJy',
#  '7MPgBFy6t1NKfkzaVHLx5X',
#  '6yon8Hb3Ur7aXXjfy4dLkd',
#  '44OUZyiPnJc4pOZw4J6pid',
#  '0iE3hEZsRnNmFPMwa5gFy6',
#  '0QjhqYzNnicAaYdXIZtqJY',
#  '1MZkLAiRHv9kaREWqxH5Lz',
#  '3XsII0AF0Ln9cpkxYDxBsG',
#  '0q8vGfDugJaZFl4eswtj0B',
#  '4Rcaazq7k1fILAJQMoMjUo',
#  '66wkCYWlXzSTQAfnsPBptt',
#  '72WMnNcM9W3Sgq8d40xzlw',
#  '3YuVcqA8VlR7qN8FOfijia',
#  '5iUQMwxUPdJBFeGkePtM66',
#  '64lXgiDJciSTokb4MPJiuN',
#  '3tEYaYV2rrsAcL6AcPxetH',
#  '6F6Mi55IrmPR5xSVQeWgLU',
#  '4brX8MJs5hxErgq48f9REO',
#  '7pVpd1e1vhUoxJSRfedfLY',
#  '5cpTgl3S3pgDjdtRtAmE9t',
#  '3sPpTsMNzlyJJx9LLJFT0e',
#  '0uQoYiYkCWrO3b3Xh7uQBx',
#  '1w2eruYH50BnPSIJ8yM8tQ',
#  '5fmCYDwxKOtKFmuztafeST',
#  '6nikjnfJXkUPQ1XDM07Coq',
#  '5lpv6SbsynNEvUVpLW74t0',
#  '2rKmNEYrQxaOPZrOWKZpOc',
#  '7MoJIfitwutdf2B9RbJddt',
#  '7gc71e0SFEdFoJnKNskWCd',
#  '5jKYiqIvEqofDxjRVSiYkD',
#  '7Jy8rrORinhl0ZmTMcYEQ0',
#  '1WE055A5d1019EAx79Rg8Q',
#  '6JWVCw5k4AT1jpOlcbfcM0',
#  '5R4Ab6YztgNL2rECssnwwQ',
#  '6BkX6DnUG80xPlBfb2zmrZ',
#  '2OoS1aZFAFscH1cUiKlazH',
#  '2qrr3pMvQBzTH37IqvuT2b',
#  '5DLTuH4A5VZB2HKpqHQR6t',
#  '10tcgQEFpS2tG6hW7nUhmc',
#  '1uxzFavoQSzR6NhzeSbHdM',
#  '6z9dMEPPksU8RAdMuHkk7k',
#  '6BvO1DgiVr0JKHLS1WXLqL',
#  '2rK7knZC1komGjPscuEXV5',
#  '1wDWUgCVsEAMiwqfqO2m9A',
#  '3Wl2XMC4tPEd6rgUFTctMU',
#  '0CJCS1CaZPy6DEKxoNBoXa',
#  '6lOPbNUxDvkUkWpJLebgs7',
#  '2QxpqFjt4AJkUepASPTOFf',
#  '1i5GkjuLcZBa478z8mpO9U',
#  '1TtNwAy3R2NLiCpBrHbXjV',
#  '0LpiKjWMfZTkPPHonlM8nB',
#  '2w3S2HbICUo6asRtK26wC3',
#  '3MYhRTonhQATwN9gO7RsJL',
#  '5lHWWhuRtSBKfH2xS6YAUD',
#  '488B6CgmGtU6dV2ii2IAKk',
#  '64bNqjxJjFQ1cJFbG5Jq0d',
#  '6RlAZ8QY4LcA4DxUUIiwmn',
#  '5BoOzegGrg5XFRR8UBDtkF',
#  '77R76aGtr3Ot9Pe566jHfK',
#  '4k5UZm89ZX0YAHUp55zpt9',
#  '7bLt0aMmFwvFfUTnxnb5Kd',
#  '0fsP8zuAl0N8eiDjlr7IM4',
#  '5MhcP8gamug67c8QRZDLY3',
#  '5fuv6LkF4hsY4NzDRdB9KJ',
#  '1eDS8ii1utvj0PjfQLrDb4',
#  '2PIXt4s3wcT1e7mjgVUHeE',
#  '6hzbRKhJHo6cfCHSnNaDS8',
#  '4yORNsoYe4XnK99EXhKhWB',
#  '0jAjq21TygX6oPGiAMl4Cp',
#  '4eqF33UK2ljNgbZ1GC1Q0x',
#  '0frQ49Tq5Kb07mAjqYVYkG',
#  '15Vpg05TUfYxIsS6BrcUD9',
#  '03L9yBcmwWgfzm4dv5G19t',
#  '17vSdpQJmAskoex4ATpz69',
#  '1O2fC3iJuHvfcjHQHq48mZ',
#  '1sGLBceU3R0cpKtQc7GihT',
#  '09buUtlQPqXrCib1YsLpQl',
#  '3X3h64J4KIdPTMifbToXDp',
#  '3vIQUVSftb98iK2WCRdNo1',
#  '1ysAvOdJgUjc6CqOQxepaz',
#  '1gv7dUAsupITkccwEqkJqM',
#  '7nHvS6UUhz2gJhj8TIROLX',
#  '679eYCtqoveynV3bra0Ui3',
#  '7bJgnHqTtP5fwZNyPNPrZ7',
#  '2uu41WgPPwOvsILlKH5S5n',
#  '6Mw2YCrPvuNL408ndJqgQp',
#  '3Xp5Q1qlO8YYn2B79fCt2w',
#  '1Pomj0gyzPNGIz7VWZxXF1',
#  '5DORjq0UUYxCEhTZ2G02jf',
#  '4W9KBjqf2lyUF6MdX0vsJm',
#  '21hoYZRx9E7FmCsw5vpYe0',
#  '7ojk4dqz5YvLKp9o3ZHLvF',
#  '4jTIQTToQuxOTTgOzRyzFh',
#  '5PwU47IWk07Ft9Pjn2Sfuy',
#  '37pUZcIley8dSEjlmE3ucj',
#  '4lRvXGgUgeduqWaxCLOUib',
#  '02wM7ucmUu1MRanSIZfgv7',
#  '1O76APr1DbfrazaAtIN6Mg',
#  '3v53dByUoc21UedVJk2OQm',
#  '35r28RDot7nPE7y9K9H7l0',
#  '1bRrNK3cnWtK0gWZsuMUo7',
#  '2wpubb22nXcfktlw8gBfah',
#  '25ZZNyJWBmBihOPFqwnaEY',
#  '6O314GiA6TQ2QBt7ReqJfz',
#  '4Zd7jRS11nqMcb8DRbgc8y',
#  '1O9DWF3578RHMxZg2nLPeM',
#  '49A6VxdfNfkrruSmfGIRns',
#  '1KmGMot8eJCgEPVjTpkkVG',
#  '3a1lNhkSLSkpJE4MSHpDu9',
#  '750BIvq0maGBlBPtlXFcwO',
#  '4SYUUlkScpNR1QvPscXf8t',
#  '6ry8KNI2uMXWLW62zCS7Y5',
#  '6eT7xZZlB2mwyzJ2sUKG6w',
#  '7F4cKRJaz1Ki9TMJCkWKMo',
#  '5dI1yHSqgmilFEqpGbqxHh',
#  '61jnrkPHpLumBf1kqGpRRt',
#  '26aVyDKN3MDAMoyO3VDB3g',
#  '2lpygKqzPFtItQ4ss3cgfb',
#  '76Gmfksb2uBzx5N72DcHT0',
#  '55EelrA8250jCznurTC1Jb',
#  '2yJVk6jfa2xAEqVb2qDFgn',
#  '23hkndX3k5judraAPufgmS',
#  '0dBeZNIXFp3P5RnNQGEu2x',
#  '0H8XeaJunhvpBdBFIYi6Sh',
#  '6M0IsaUX4GNyto4niSegfI',
#  '0z18nuwBppfJT0lwt5YATH',
#  '4YpPQaFeUHlBAE6AjvlCjP',
#  '1QWmKmqhv5zcsS3v45FNl0',
#  '3xfxZi6Ue0ZphUknB5fnba',
#  '5R6nhJJnn2MhllmUq6ix08',
#  '2puHJmjL4jvO19aEA7kzcb',
#  '4jV7TPCxNDcR6ILr4DgG9J',
#  '7tEtjwh0pU7NDwkRYFEfyz',
#  '73v4ooMlKgIEBiitH9t1Xe']

# %% [markdown]
# ### Extract audio features from returned track id list

# %%
audio_feat_1 = sp.audio_features(tracks_id_1[:100])

# %%
# list, with embedded dictionary as items
len(audio_feat_1)
# Out:
# 100

# %% [markdown]
# ### Creating dataframe from returned audiofeatures

# %%
df1=pd.DataFrame(audio_feat_1)

df1=df1[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df1
# Out:
#     danceability  energy  loudness  speechiness  acousticness
# 0          0.417   0.447    -6.732       0.0290      0.593000  \
# 1          0.497   0.507    -8.075       0.0585      0.214000
# 2          0.817   0.865    -3.485       0.0321      0.087000
# 3          0.418   0.947    -6.825       0.0727      0.000412
# 4          0.266   0.190   -23.082       0.0409      0.693000
# ..           ...     ...       ...          ...           ...
# 95         0.581   0.859    -3.475       0.0308      0.035800
# 96         0.649   0.618    -5.694       0.0672      0.483000
# 97         0.517   0.481   -12.569       0.0512      0.661000
# 98         0.358   0.955    -4.800       0.1570      0.000227
# 99         0.825   0.393   -10.875       0.0771      0.039000
#
#     instrumentalness  liveness  valence    tempo                      id
# 0           0.000000    0.1290    0.225  145.318  18p0zFMIvihb3iA8xAYgGH  \
# 1           0.000005    0.0948    0.192  119.432  7MTIDmToGs0I5Oue9V0CHl
# 2           0.008040    0.0960    0.781  120.031  1QVsmXvya0zH19OsV9uEvW
# 3           0.016300    0.3800    0.261   80.639  5ZWkiOzFnu0p9Uzss1U0yh
# 4           0.001420    0.1130    0.280  132.554  2jm4r2LruBBzaEM1Q3rNOg
# ..               ...       ...      ...      ...                     ...
# 95          0.000000    0.2590    0.572  127.056  1TtNwAy3R2NLiCpBrHbXjV
# 96          0.000003    0.1660    0.421  125.977  0LpiKjWMfZTkPPHonlM8nB
# 97          0.002280    0.0709    0.825  101.412  2w3S2HbICUo6asRtK26wC3
# 98          0.013500    0.2770    0.110   82.651  3MYhRTonhQATwN9gO7RsJL
# 99          0.000905    0.0609    0.620   98.940  5lHWWhuRtSBKfH2xS6YAUD
#
#     duration_ms
# 0        239333
# 1        197120
# 2        234973
# 3        267427
# 4        137867
# ..          ...
# 95       281013
# 96       219147
# 97       190822
# 98       299120
# 99       223507
#
# [100 rows x 11 columns]

# %%
df1.duplicated().sum()
# Out:
# 0
