# %%
from stackapi import StackAPI
from bs4 import BeautifulSoup
import requests as re

from time import sleep
from random import randint
import pandas as pd

from datetime import datetime, timedelta

# %%
import os
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_id = os.environ.get("SPOTIPY_CLIENT_ID")
client_secret = os.environ.get("SPOTIPY_CLIENT_SECRET")

sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

# %% [markdown]
# #### Find top song per genre

# %% [markdown]
# **!** Spotify doesn't expose genres for tracks, the closest you can get is to check the genre of the album the track is on. Genre is however only part of the full album object, and not the simple album object. To get the album's genre, first requesting the Track metadata to get the album URI, and continue to request Album metadata. You can also get an artist's genres by calling the Artist metadata endpoint.

# %%
sp.recommendation_genre_seeds()
# Out:
# {'genres': ['acoustic',
#   'afrobeat',
#   'alt-rock',
#   'alternative',
#   'ambient',
#   'anime',
#   'black-metal',
#   'bluegrass',
#   'blues',
#   'bossanova',
#   'brazil',
#   'breakbeat',
#   'british',
#   'cantopop',
#   'chicago-house',
#   'children',
#   'chill',
#   'classical',
#   'club',
#   'comedy',
#   'country',
#   'dance',
#   'dancehall',
#   'death-metal',
#   'deep-house',
#   'detroit-techno',
#   'disco',
#   'disney',
#   'drum-and-bass',
#   'dub',
#   'dubstep',
#   'edm',
#   'electro',
#   'electronic',
#   'emo',
#   'folk',
#   'forro',
#   'french',
#   'funk',
#   'garage',
#   'german',
#   'gospel',
#   'goth',
#   'grindcore',
#   'groove',
#   'grunge',
#   'guitar',
#   'happy',
#   'hard-rock',
#   'hardcore',
#   'hardstyle',
#   'heavy-metal',
#   'hip-hop',
#   'holidays',
#   'honky-tonk',
#   'house',
#   'idm',
#   'indian',
#   'indie',
#   'indie-pop',
#   'industrial',
#   'iranian',
#   'j-dance',
#   'j-idol',
#   'j-pop',
#   'j-rock',
#   'jazz',
#   'k-pop',
#   'kids',
#   'latin',
#   'latino',
#   'malay',
#   'mandopop',
#   'metal',
#   'metal-misc',
#   'metalcore',
#   'minimal-techno',
#   'movies',
#   'mpb',
#   'new-age',
#   'new-release',
#   'opera',
#   'pagode',
#   'party',
#   'philippines-opm',
#   'piano',
#   'pop',
#   'pop-film',
#   'post-dubstep',
#   'power-pop',
#   'progressive-house',
#   'psych-rock',
#   'punk',
#   'punk-rock',
#   'r-n-b',
#   'rainy-day',
#   'reggae',
#   'reggaeton',
#   'road-trip',
#   'rock',
#   'rock-n-roll',
#   'rockabilly',
#   'romance',
#   'sad',
#   'salsa',
#   'samba',
#   'sertanejo',
#   'show-tunes',
#   'singer-songwriter',
#   'ska',
#   'sleep',
#   'songwriter',
#   'soul',
#   'soundtracks',
#   'spanish',
#   'study',
#   'summer',
#   'swedish',
#   'synth-pop',
#   'tango',
#   'techno',
#   'trance',
#   'trip-hop',
#   'turkish',
#   'work-out',
#   'world-music']}

# %% [markdown]
# #### Selected genres :
# * blues
# * classical
# * country
# * electro
# * funk
# * hip-hop
# * j-pop
# * latino
# * metal
# * pop
# * punk
# * reggae
# * rock

# %%
# loop this list throught the sp.recommendations()
# extract albums IDs from the reco
# extact tracks IDs from albums
# reaveal audio_features from tracks
# bin them according to audio_features

# %%
genres = ['blues','classical','country','electro','funk','hip-hop','j-pop','latino','metal','pop','punk','reggae','rock']
result = []
ids = []

def reco_loop(x):
    for item in x:
        result.append(sp.recommendations(seed_genres = [item]))
    for el in range(0,len(result)):
        ids.append(result[el]['tracks'][0]['album']['id'])
    return ids

# %%
# Returns Album ID from first element of each JSON from each genre.
album_ids = reco_loop(genres)

# %%
len(album_ids)
# Out:
# 13

# %%
album_ids
# Out:
# ['0cw6Sv7IwZ87aLPPvNPSd0',
#  '2hvHI1YepnxxbwVqru5VTZ',
#  '79uExtsVJH2aNcS2Xu4Cim',
#  '6kVK2SrA41p9MngYbkMXF2',
#  '0Vj6k41UiNc3GUH8kEig1i',
#  '4Csoz10NhNJOrCTUoPBdUD',
#  '6whaxzm5MNttT7nVl3XO8b',
#  '1lOegkmEfMEMhHy0loZKXV',
#  '7G2PY8yve3Db0PeGsosb4x',
#  '3yWRq9Dd2UO5xyqxTjLDmp',
#  '53W7O35aXGUa1AyhXYtLpf',
#  '55fxaMIEdo2z7n4SW7qfKD',
#  '6r7LZXAVueS5DqdrvXJJK7']

# %%
# extract songs from a given album

def get_track_ids_from_albums(x):
    return list(set([i["id"] for j in x for i in sp.album(j)["tracks"]["items"]]))

# %%
get_track_ids_from_albums(album_ids)
# Out:
# ['4hfPI0Wb6Vrb6bUv6BNrON',
#  '1UhmANULygND830HDoa6iM',
#  '0i735GMaAdxERa6k563yKp',
#  '6YFewEWHZB04bJfGYgbYCC',
#  '6EKrBVHDk20hwjYWGPQQlF',
#  '7u17w29WWTiftzGHs8rhpw',
#  '6G9sWidCZ7e1CVv37hjCj1',
#  '2j4AKjlKl7iDVLWJ3rKifU',
#  '4BZcmWwDcnNXQuVEaZA8a5',
#  '5ucHc0xNuzMssqnr3FDnxp',
#  '13adZXD5qXvZk0OtN6WUEy',
#  '7iqWZNpHBAK5jE6e9gPKj9',
#  '1f1vUJ1eAY1swaAnDxWd23',
#  '0kBZUOxX4XrTu6spRQiUOt',
#  '2nSixAWlDX7TW6Zlui1sRw',
#  '5cikVJA2ExOI9TTkC06vkN',
#  '236eGPBmuMNkPWBpGN2Cfl',
#  '1cjRGRxMNA8bdpFMbupG0w',
#  '77lGafvlU68CeHgB2pkHC9',
#  '3pktmNAbxSBjCDD5u2meYs',
#  '2TElexeJMX3OyXil4DWbVs',
#  '4rQyDKHWokzTRo8axBDlz0',
#  '0nhCLRoqki3JF0fGbuSOrV',
#  '0fAnYkjbAnYz1qzOWimdjT',
#  '6mOOqBUMPHovrbncBwMdQq',
#  '1PSBzsahR2AKwLJgx8ehBj',
#  '3vLUBXxEyJdEyzrHIeEAxY',
#  '7wqWSTBpYjsFX4JDDQaU1w',
#  '6B39pYK4m4tyWioWnjRq2V',
#  '1wjyGxvNK5POKbIfNroB3E',
#  '7uMb8RUN7S0bXdWXpI2euL',
#  '1bLXh09ihiXb3S5hkdRvci',
#  '5bG2wMLua5ywaXjwmSQ42r',
#  '2h9QegkylwprytG4AE4Yzc',
#  '3YROTILzpPbedQXDgeU9mb',
#  '15Q2Tp792e30i2AfJmGwYz',
#  '7w1JDEjmXYw2DwllK1EwCg',
#  '1Y373MqadDRtclJNdnUXVc',
#  '69SG2ZqfdaVaTnuZ3AYge2',
#  '7iQ8cowVQIQY7I4LwlABSJ',
#  '5Y3TM2M4VqyhiJzWtxmG5a',
#  '22NAKlgAf5X2kjaLnG7PkO',
#  '48al0wZBGItngZQZED80WO',
#  '6iHv5JhHKQfqdIdjfbaRNu',
#  '2xar08Fq5xra2KKZs5Bw9j',
#  '2dwQ9i7fP8in0XO15KYCOf',
#  '2DdNW301OxnEHx8m4WHHKV',
#  '6mXwoyzrpb4T5Iveoo4k5G',
#  '5ZUppVGTUmzQrIK3CEtoOj',
#  '6C6kmwabmhtrPRQeKi0qdl',
#  '4UmehW6tTXGC7HsuIGujMR',
#  '1BzV9V9jmSgaFeLgxN1m4N',
#  '6JyvZh5fvR4FbWwz15DmrX',
#  '1Bt9JonRMKEX9UCGMLEhKL',
#  '6nDqFWB9MtQ9rTjmm3gDAD',
#  '38GIXryQTvtuteKojD6YIv',
#  '4PwPgoMh7YcuHn9OwNtVRk',
#  '2VDg6h3Qr3F8UuFVInQxE6',
#  '734xplxSpoW22U5OeeZcr8',
#  '24GaspdcJWLts2R1wurDfW',
#  '6mPNH3gq9M3j99UPnISxm1',
#  '7xdwUyl21prW7Xr8Msd6Hn',
#  '4b0XF7CDpJEBAdVHMw7amV',
#  '1J31G5jTWM0I9zlboi7zUW',
#  '1T2apRoi63qbukKzPy0fqY',
#  '5Y0o96Jc5A4juQ0soKpQAR',
#  '6JiLtrIPfEJo1wXbMAGdr2',
#  '7nLgLjMV2f0eg9w1rUgKWK',
#  '4rVdFxNdR2lEkxrx7ctmE6',
#  '1IoQsA58Sj2odO1pp2dEVe',
#  '21DY95zGkJDntDw2fMH86y',
#  '6Q8ttpzZFuHFYXSN3mDNLI',
#  '50hyjSMdB4dkLT0pw1LWxx',
#  '0FzQLm4PKsud2Ee5eBM7jC',
#  '28GiGdDsLRRCaYCrl9Esxr',
#  '4uQ7wYsuL0DryknoDc11Hk',
#  '3e1uiOqAB61btLHXK5p8o4',
#  '5R08q0FbWLLQ5Bec8lQ3am',
#  '7y4c52JBP5KL2e2Ld2g8rJ',
#  '46U3t69W4bXFHPNpeJ7EPO',
#  '3gLlcZQMvpwgtV9THHXrGp',
#  '2vSzbAjeftc7pxnyIM1QPf',
#  '73ZTeyfGTmfSFFfqoKMKxR',
#  '0eh4omqA9nvxnjMyqgX542',
#  '7As8h8LJTMIritB8QwSmqr',
#  '0Ia2Lt835EdMI0usPh7MzU',
#  '2UCF576iSyYqVVkLzQYA4Q',
#  '2EIipmkJrkZXhnemmBq5Sx',
#  '1deetO7jeQqMH2C7kSH32a',
#  '3zmn4Ot71BmDswutx83lAW',
#  '2b8xbWvck5yh9vvEogsfqa',
#  '0RkDnwFmI3zPopB210Dq98',
#  '3twMzAYLVCQGfqbkgkwt8D',
#  '4Jg386FgtccP07bKqX74o0',
#  '25wtKQmn7Y9CL9FOuEgozT',
#  '2laaXX03sRgEqx1LWttsWy',
#  '6TneyXtUiPoG4cF2DHbAKG',
#  '7MrdOSEVc6iZhHFImhRx6C',
#  '0pdH0sCWdN3IofgTGBkiLA',
#  '2HYzMQl234E27nM7mIhYgB',
#  '7eVE5ZeGKSDX6WHT595Sw4',
#  '5JNfwF7ZoOkXJWZgcWEnQL',
#  '1wTo95wUFOA0AcAOGAEkeS',
#  '6xzSG10Ak6VWY57leLYWDs',
#  '2IgxI7KokwQ7egFvYqB4U9',
#  '6TnJUMeUH6Ze6oWi5rLMIP',
#  '2nSXFruCory4EyX08HYwcf',
#  '1TCBXfWeaSNLryi1jCjHIw',
#  '4sbHGlsIw5ST7u9s7hLxME',
#  '2cpXGHCXMVYenUo7va9arE',
#  '0pNFYMYMtcjNmTBBZ4uSTf',
#  '2Z5mTe2cWkQxT0n1RWy0J1',
#  '7jRp9vowxo0njooxlFY10d',
#  '24OsKc9qr5IFyiaHNCAk3h',
#  '36VxfQuNM9yJyBD0hAZd1q',
#  '7H6lDjQ509hVPiN72wlwzM',
#  '034BozaXxmv5XL2b7lBdoB',
#  '2b8hC1KbIcdgGkGSzrvggS',
#  '1whKEAnnyyyri3yxvMKJnv',
#  '01rkG1nIcspFnzfOsin5oA',
#  '4pj9p5PSemdAV3lBFjCTrW',
#  '2CAAwb9GbvargmIqQ08fqC',
#  '7xT7ZV55F0z7l5FgKH2Ajq',
#  '72QumnYJ2ZsijxD3ikJtjU',
#  '2FfU6BLvwYySpKnVmG2XJh',
#  '3jKh4PrpTp16PeQZpjY4QK',
#  '6yHZ09mUcQRZtWBYW73OoQ',
#  '6SQMnEMwiwb8j6Mfdb2JYz',
#  '5WgOELT1kPGBVCHVHvzIHS',
#  '1tiWZCFQuekR0EVmxYUXh1',
#  '7FGZRBgeCYLdE2qGjoqr6U',
#  '6ejipC6dh8CGi2WiUACOvN',
#  '1oUcpCvpLemOfxtwtoMykL',
#  '1l6gZaMpDlsDbPQ2K2hnjg',
#  '4v9VnkBuQHP6sGYaDJwNfV',
#  '5Q6z8rqbH1CfYaUOqktJbE',
#  '1sawcLOEaUJ2yGi8T10vNo',
#  '0oQtjAjUeksVd9gHE5fl02',
#  '0QxYdrQxcTUKTHtDpfvETh',
#  '4qMb3Vr3Y3eqja38lDDC6I',
#  '1MIXskZ4BlprXfMFvP3wJD',
#  '0m5Hlls9pfFMf1q1LZvM0t',
#  '7GKiBHjFfvPRNqqOuRYqLB',
#  '5bSuOVGedV6hearz2e0yaP',
#  '1WxA0AsbXTm7w0Q5QvHTk3',
#  '00mXfVfSceT0DwTdG59hDP',
#  '2YVGNWKALkV9hGJU7CAcb2',
#  '4FneYKy7H8hsj7ZAjyE179',
#  '63BSDisduHQUOVqqL8xiPe',
#  '7DJsL4jyXA39GDiHFQYQ0t',
#  '6ZVNl5vD86IL6c4ikYgU78',
#  '1u1VcXquBfZfu7dc8PVYVc',
#  '0r9rzx0szaqipQxWMA5JYq',
#  '21KyfcMMFfFUvuMpS23yIv',
#  '38T3v6YEHh87w3WoXong3N',
#  '5nAvEO1PsWDklhXmh24ovC',
#  '3t3EJmyOzTf5ZK1PuvFcxt',
#  '5HEFe9Fop0mr5xxJsonvPA',
#  '4SotXdTLGKPJUJ3fvQSskK',
#  '6HMOqVZQ0IS4MKynfkrKpT',
#  '1CVvABk2R2mpGE25VV9hiJ',
#  '4YmWEzX4FjscKMIMasVGgp',
#  '5hfpu8saHLGedbHRtNCYjm',
#  '6AdCufBsRJCWTpIPYJM4MV',
#  '79VVVXyBvRQ5fCenWLIeUk',
#  '3HZeQUHLNVNut1HsVxHq72',
#  '0Cf8nVHIjpJpCqCuqLZeOu',
#  '3oaJNWfvlJGPiP00YqmR39',
#  '7fFXNgd7oadEwwki2D2HDB',
#  '7lkouEWhQuhBtNbukl3JGf',
#  '5P11rW6aJErF37MTfRZS31',
#  '4ldUfPQ0QwC5c6zDifFINZ',
#  '5W3ih1h8VhaLDIvwgMIRvQ',
#  '38reaI05eLl8V5CVAzq5BH',
#  '6q2hNotcUhZ3v8AMVhhrfO',
#  '6aaICB5rdTSmFrQZqgNzTf',
#  '5Ov9sO9wmvDo6v66DOqNtS',
#  '1VVkbfJxNdNKokDNTQ597h',
#  '2rd9ETlulTbz6BYZcdvIE1',
#  '44OimNkuIqybUyUo6evGS7',
#  '3IOQZRcEkplCXg6LofKqE9',
#  '4m6PR2AVBoOHDoYjWAsRSp',
#  '0rOnWPTKlfd4I1zxdENM7g',
#  '09OCGlZZrDsuyoHasLVPEx',
#  '06RUl9rjiV0OhczC0yQ0YA',
#  '72YRB6ar59nBsNdnn0cVdD',
#  '3JPZKiZKQOsCMJmysdVcAZ',
#  '1Ln0KAumoyNYDefSPWY5gy',
#  '1r7sUxDfWAHdnTbHYusgI0',
#  '2CFqkvIQTkIUg6046J36IY',
#  '7MDUVH4ITohsIjdynRwCJp',
#  '7hUMwKkTuUhc29szmBvkfZ',
#  '2rQsg6LF9Ylm31vtYCjQvd',
#  '6ltoqyE3CMIO1q81aBVRPi',
#  '3QoFJiEWJ0LnDwch93MdZf']

# %% [markdown]
# ###

# %% [markdown]
# ___________

# %% [markdown]
# ## SONG FEATURES EXTRACT INTO DATAFRAME (prototype)

# %%
genres = ['blues','classical','country','electro','funk','hip-hop','j-pop','latino','metal','pop','punk','reggae','rock']

# %% [markdown]
# ### Extract album ID according to genre

# %%
genres = ['blues','classical','country','electro','funk','hip-hop','j-pop','latino','metal','pop','punk','reggae','rock']
result = []
ids = []

def reco_loop(x):
    for item in x:
        result.append(sp.recommendations(seed_genres = [item]))
    for el in range(0,len(result)):
        ids.append(result[el]['tracks'][0]['album']['id'])
    return ids

# %%
reco_albums_1 = reco_loop(genres)

# %%
reco_albums_1
# Out:
# ['3Vp5uEx8koFke8NyfElrlD',
#  '1NVw0NWLA3NJwQy89A2pd6',
#  '5L0e8X6Mf9lfjs2miK2WUB',
#  '38ojnzxpPFT09ee03aCTK7',
#  '1ZTr1RtD8WP2El0vkvI1R2',
#  '3arNdjotCvtiiLFfjKngMc',
#  '6VxPrvnkHuHgpD1043Xlga',
#  '5t3hXKG2uyhYSlMaRViaEH',
#  '0VvDozXY0AHdsWhHJAWWTF',
#  '2SCQAZZ5pc90l9SPBsWCIQ',
#  '1gsyJWUvwjnsNgYUxpOfLR',
#  '2ugVVkmRbNvW3aczv66i19',
#  '2xSppFiPUTWqZ9cdF6CQnY']

# %% [markdown]
# ### From returned album ids, extract all track Ids

# %%
def get_track_ids_from_albums(album_ids):
    return list(set([i["id"] for j in album_ids for i in sp.album(j)["tracks"]["items"]]))

# %%
tracks_id_1 = get_track_ids_from_albums(reco_albums_1)

# %%
# list of track IDs
tracks_id_1
# Out:
# ['4VZ0UOLwnTnQSLZJme5lyQ',
#  '5dFwDUe9DMl28LpROkhZu4',
#  '1L4ca7Ti3S795YrBdTzE4T',
#  '5ZdziocLu1aGzSRixpW3rr',
#  '6lIyXleBCaWzOn9Ltjg6E5',
#  '2N3U8uTYhjX2KwGT0pf5x0',
#  '2WxzLbJfPA2vJGxQiKd7Jq',
#  '7dUdMZqfGSIt0ZkmTOgRLA',
#  '3twxRT6f42UpjE2xUVcdG3',
#  '6O7Et1ArYoS9nOKwRjK3Oq',
#  '2C4XQsZFeze4yMatFzY9M2',
#  '1GOuHB20lqVyxv3GdxovPY',
#  '3yju5QYFjndmGvaG2wVvPv',
#  '1dbLmUsZJFTbHCsAGE4x2D',
#  '6wwPtKxaMEbQYc6atQmhTE',
#  '4yRMcsWVWCYGQPj5am1UCP',
#  '4JMvnscEzgZNXzppm8V0Qs',
#  '3nHbQNMuGuEtIVhPGVfFbF',
#  '3zQN4zs4BiEnSI3sh2PZwa',
#  '5EVXcYg6G8at6IDQbi9M2F',
#  '7vcryRa5cl0iJ4Bif3dKWU',
#  '3943Xwoj2F9TfuLgHDYM8J',
#  '341LEcA134Ms2ri6WhJUwV',
#  '3I8MbKRkS2IBDuslhCS3iT',
#  '1Wdhwm3TtIuZvohSZNpZwP',
#  '4kBbLU8WnCWknsYXHPCsv2',
#  '3yXknYHbkcSca92PSSVniX',
#  '5OGzWbdJVqlHGIVqqZyoPX',
#  '44YNLnTujChFsBmuVts4me',
#  '06M6ANp2yXdhpGssKPhT69',
#  '18gj6WTWnjJA5s7FSTVQwj',
#  '3EVgZBKWXY6xOtS8mrhW1C',
#  '5w3rCESBlHOV2CLYUONlDO',
#  '67h3AeLwglIaguXt95F0jQ',
#  '4WKGfdb5aYHv4srH7zuclB',
#  '2XKmD2Fy4rVWzL7CFDpd2s',
#  '2546X1mmMxfa9ZtFfVk1E0',
#  '0X01f4iKEmUgco8ma24Wng',
#  '1q1czFTQvKFTlNGXO4qLUj',
#  '6AHNkRbVzkh95xilnYzDT7',
#  '6Wo5YxkdXgwzKQZbDg2r17',
#  '6pVSAHKEKOWxDcfr8haIGe',
#  '0WcZxRUxHKp07RtI4vnBFK',
#  '0o4ETDFkxzmbYRGhyTdhNS',
#  '4DvfGBOSlrzC9QeGEeQGxv',
#  '7j2fN0rZh83ZbPbuNJH6pF',
#  '4emfQeHkPHPZjMTmJtQflg',
#  '22q0Q9kJrricJ75sIp7gTy',
#  '19OmsLCVYcEGoMgmbzZxPv',
#  '1rykvAlTc3RqvyDrRztlAI',
#  '4YXlJiIXYad3yWAYqC5zOa',
#  '5BvR4B2flWZ8Mh4fBgzJDf',
#  '4g83J52bPalyuNU9Y1Kuq9',
#  '7yGJcaSJgpgXamjmXBCb6j',
#  '5Blc6gorvnXeldwIwz1Sfd',
#  '7gHkDNieGzYmyuC7E1Xbxw',
#  '6TWgRy0WZEyPFIkYU505s8',
#  '4fV93JA79e1YCigVUV8mfe',
#  '1CYSLNSMRvcsLbxIJuChZP',
#  '0sNKDMdRAGdI5C9afVMGEx',
#  '16b7YDt2ys2zrXxr41pxt9',
#  '6Oexp3W6bv5LBzsS171iqN',
#  '25Sd73fleKUVPNqITPZkn1',
#  '26Aok9jFEw5YT1XAnyphbw',
#  '6vkoFgpGHnQ9mwbZCY2yDh',
#  '6J9FgTr3z44Bw6ABeVL415',
#  '1m1yWMD4yLUESsFOhEa6Ck',
#  '6o4uMkLbBrKS7a6vpNThpO',
#  '74uwIzBc3pPWLin6ypQd32',
#  '38W6hzEOvM50bUP6DaO9bP',
#  '7vn037pBVIJo916W1BCtE7',
#  '2yyQVP7siRFgduvFFPL6PC',
#  '7mlkO7fkD1tJrxoqOMGzqF',
#  '4dWxZ4MghFNjpS0QJuR9eK',
#  '64aTsM53REi7z5oCvep1EC',
#  '1yd6mE2x3p13fcXPynCkKb',
#  '5TphzFf2iv0l3VrFHN08kN',
#  '15nGklw2h1ocblZec7hETL',
#  '5cYZm4KeDKM8Pw8z5XRKJt',
#  '2sBHQfX9QxJwGcdutAj6Pj',
#  '5H2B44TCS483P9e2gfdfMK',
#  '67OtXekkKRL5DZX3zEpdnA',
#  '2JqNypbkqPNtCLBeuUqmnm',
#  '0oTGa77jJ1H5joTG5SvxFj',
#  '2zYjM0an9pTfxCDRimSRia',
#  '2zIA3HbVOu5LiOk6akCtLd',
#  '41OlawxqIkhewGZe2NR9Qk',
#  '1hqSh8mzSOjritWWdpwVwy',
#  '47hxi2GtzrNpg1gaq0jmnX',
#  '3uvLTz6fGzigCqqgroho25',
#  '1CGP5ioAXECjvTJdMTvX0O',
#  '1j6kDJttn6wbVyMaM42Nxm',
#  '7nBCUygrEGaU0Hvr9u6ntW',
#  '7dK9JJXrbDFc29n23BqUso',
#  '53Y16ElHFkfFhzl3aIXXCF',
#  '7sLDnUauivS2vN6Z9EfUJT',
#  '17k0ItD5xU09ORtsUrb2dO',
#  '5v9e0mJg74D7cFfYxKDJH0',
#  '4WIyNmRe7htCNYwMOpF18p',
#  '5f8KBsReTKtWQl9vrWhrtg',
#  '2N3LQk27fglVbVqQ8zA6lQ',
#  '2LVsEfa7e2yeJNIQzMzPbQ',
#  '06fBP7sl8wRreVG1wAGAVp',
#  '5zomeVxT4z5tjOZydRSxXP',
#  '2pxM1i3B5CpUZNTy8laF3h',
#  '5Ukh8Rve5owCW6ZujZaBVB',
#  '3RySVukMPe4R7lAP8oGI17',
#  '1OPTt43pJt7iDlvvdQnTD4',
#  '5lEjdcCF84tGOx54LbZZKC',
#  '3D96ZMh1zs0hcEo7vS0Umc',
#  '5dQz7584NWBBTlXUxhc9rK',
#  '1G01569Zj7IzOvLf5vaCvQ',
#  '525iaNTGlxLokffUrHzrOg',
#  '35Dh7WSf3vVJZ5UYPuXlxk',
#  '4p3r1bncJIkS8NtIs2QNv1',
#  '2IjgKCbrk8CtqmsOC5DhVd',
#  '1lbE2KjX5w4nZzJnL0Hc0S',
#  '0rBMP6VVGRgwnzZCLpijyl',
#  '5m2C9yTXkC2yzoFJMPmgyX',
#  '64h3hMy1ULj3Y2xcAmOuiJ',
#  '6br4Pc0BzU6dTD5fEmks2i',
#  '5jOOZRXH9CBuaHsYekcTRh',
#  '3jnaWFiF1qcyTWQNaguTPc',
#  '6vcFHirl6xkhzNLgZZH6QN',
#  '37hlOoI4GBzhEpExqsQqSu',
#  '4MAoDFNczHbMXr6KREF5gJ',
#  '383vhYfDjexc4xUlzN1ZRq',
#  '0keFHPjbxEtWt2D6rFlky8',
#  '5UM4eoahsyDfwzUHV9ftqc',
#  '04PfKFHsgOfD5Gt9YM3bkM',
#  '4s9z3AXSCPD1yonFAaQ109',
#  '0Oj7jBfkbqEm8VdeV0Po1c',
#  '4WkSgLRq0KAV7eWxtlTj00',
#  '6DPZmWcljW3XCfMNlnqy9r',
#  '6Mu8KPJR2l7Kygj4uSQsoY',
#  '4YYW9IVaVAgdSk0GA5OJjC',
#  '56F16A3P8UgfG8nkBdUFB8',
#  '0WQ6YEBUPLCNT2DQ2GXoI8',
#  '6xPQovYVUONEpw6jxaRRnr',
#  '4u4F83SM9XZ7f4zjN4pB14',
#  '2gAGWaK4wvt2xrFUlR4mK8',
#  '4gROmBK9BE9ZaV9a2ICxNZ',
#  '14TyEaSTlt6b8hWYp6reW6',
#  '2mNRZ3ewIzRD5JU8M7yOZ2',
#  '6yMxfx9wpiuhhdb8vHDVMu',
#  '7eVnrWEXTTedaLxDTOYzuV',
#  '4S7YHmlWwfwArgd8LfSPud',
#  '0QkLpSDK0eAuy3dyLe8bpu',
#  '1BhomD29bHcV9OvwJOinFK',
#  '5X5U0Nc8PKvzu4zFtZ63Um',
#  '5mHtsR7GougbW7Yd5esjFB',
#  '02GBtzxf70cvt8wxxhKnyG',
#  '2NUwA4xWCIxU3TVw9Un3nK',
#  '41FxRrhwqe2LvFcU3WapS1',
#  '4wuOxtRDeD9YiQOcmgay7e',
#  '6C3dzW9wasv9K0safs7NzT',
#  '3BHyWRyE82VPFKJgIXy7gp',
#  '7sO969CnGNCZ7kDravLtPO',
#  '6b5uymxUFq8cv2LPm8hUST',
#  '1Be8uP1reYkZ3CrFZVAk6f',
#  '06gD2ZtK3Dzc1BYqWExQJJ',
#  '29ZSk6XmWPx3DX69xBb7Yi',
#  '5ebeM1o4vJnp1JT4GXUMSP',
#  '55sbVAJ3i4yfypp4arTALq',
#  '3HNCMMsR5ScZE87K6olm5A',
#  '4ztx0lpE5Vx3yg7FereOtS']

# %% [markdown]
# ### Extract audio features from returned track id list

# %%
audio_feat_1 = sp.audio_features(tracks_id_1[:100])

# %%
# list, with embedded dictionary as items
len(audio_feat_1)
# Out:
# 100

# %%
audio_feat_
# Out:
# [{'danceability': 0.766,
#   'energy': 0.805,
#   'key': 8,
#   'loudness': -2.771,
#   'mode': 1,
#   'speechiness': 0.0443,
#   'acousticness': 0.705,
#   'instrumentalness': 0,
#   'liveness': 0.0928,
#   'valence': 0.967,
#   'tempo': 114.195,
#   'type': 'audio_features',
#   'id': '4VZ0UOLwnTnQSLZJme5lyQ',
#   'uri': 'spotify:track:4VZ0UOLwnTnQSLZJme5lyQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/4VZ0UOLwnTnQSLZJme5lyQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4VZ0UOLwnTnQSLZJme5lyQ',
#   'duration_ms': 168653,
#   'time_signature': 3},
#  {'danceability': 0.828,
#   'energy': 0.592,
#   'key': 8,
#   'loudness': -7.08,
#   'mode': 1,
#   'speechiness': 0.0501,
#   'acousticness': 0.678,
#   'instrumentalness': 0.000107,
#   'liveness': 0.187,
#   'valence': 0.795,
#   'tempo': 101.646,
#   'type': 'audio_features',
#   'id': '5dFwDUe9DMl28LpROkhZu4',
#   'uri': 'spotify:track:5dFwDUe9DMl28LpROkhZu4',
#   'track_href': 'https://api.spotify.com/v1/tracks/5dFwDUe9DMl28LpROkhZu4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5dFwDUe9DMl28LpROkhZu4',
#   'duration_ms': 436760,
#   'time_signature': 4},
#  {'danceability': 0.234,
#   'energy': 0.828,
#   'key': 8,
#   'loudness': -5.048,
#   'mode': 1,
#   'speechiness': 0.0412,
#   'acousticness': 0.00119,
#   'instrumentalness': 0,
#   'liveness': 0.158,
#   'valence': 0.404,
#   'tempo': 168.073,
#   'type': 'audio_features',
#   'id': '1L4ca7Ti3S795YrBdTzE4T',
#   'uri': 'spotify:track:1L4ca7Ti3S795YrBdTzE4T',
#   'track_href': 'https://api.spotify.com/v1/tracks/1L4ca7Ti3S795YrBdTzE4T',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1L4ca7Ti3S795YrBdTzE4T',
#   'duration_ms': 265520,
#   'time_signature': 4},
#  {'danceability': 0.505,
#   'energy': 0.463,
#   'key': 7,
#   'loudness': -10.653,
#   'mode': 1,
#   'speechiness': 0.124,
#   'acousticness': 0.518,
#   'instrumentalness': 1.57e-05,
#   'liveness': 0.715,
#   'valence': 0.659,
#   'tempo': 105.661,
#   'type': 'audio_features',
#   'id': '5ZdziocLu1aGzSRixpW3rr',
#   'uri': 'spotify:track:5ZdziocLu1aGzSRixpW3rr',
#   'track_href': 'https://api.spotify.com/v1/tracks/5ZdziocLu1aGzSRixpW3rr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5ZdziocLu1aGzSRixpW3rr',
#   'duration_ms': 214924,
#   'time_signature': 3},
#  {'danceability': 0.167,
#   'energy': 0.0581,
#   'key': 2,
#   'loudness': -21.249,
#   'mode': 1,
#   'speechiness': 0.0356,
#   'acousticness': 0.969,
#   'instrumentalness': 0.363,
#   'liveness': 0.0873,
#   'valence': 0.0733,
#   'tempo': 75.979,
#   'type': 'audio_features',
#   'id': '6lIyXleBCaWzOn9Ltjg6E5',
#   'uri': 'spotify:track:6lIyXleBCaWzOn9Ltjg6E5',
#   'track_href': 'https://api.spotify.com/v1/tracks/6lIyXleBCaWzOn9Ltjg6E5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6lIyXleBCaWzOn9Ltjg6E5',
#   'duration_ms': 294133,
#   'time_signature': 4},
#  {'danceability': 0.394,
#   'energy': 0.661,
#   'key': 4,
#   'loudness': -8.684,
#   'mode': 1,
#   'speechiness': 0.192,
#   'acousticness': 0.00996,
#   'instrumentalness': 0,
#   'liveness': 0.343,
#   'valence': 0.335,
#   'tempo': 149.818,
#   'type': 'audio_features',
#   'id': '2N3U8uTYhjX2KwGT0pf5x0',
#   'uri': 'spotify:track:2N3U8uTYhjX2KwGT0pf5x0',
#   'track_href': 'https://api.spotify.com/v1/tracks/2N3U8uTYhjX2KwGT0pf5x0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2N3U8uTYhjX2KwGT0pf5x0',
#   'duration_ms': 260987,
#   'time_signature': 4},
#  {'danceability': 0.43,
#   'energy': 0.522,
#   'key': 1,
#   'loudness': -10.372,
#   'mode': 1,
#   'speechiness': 0.0768,
#   'acousticness': 0.117,
#   'instrumentalness': 0.31,
#   'liveness': 0.952,
#   'valence': 0.087,
#   'tempo': 113.807,
#   'type': 'audio_features',
#   'id': '2WxzLbJfPA2vJGxQiKd7Jq',
#   'uri': 'spotify:track:2WxzLbJfPA2vJGxQiKd7Jq',
#   'track_href': 'https://api.spotify.com/v1/tracks/2WxzLbJfPA2vJGxQiKd7Jq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2WxzLbJfPA2vJGxQiKd7Jq',
#   'duration_ms': 218547,
#   'time_signature': 4},
#  {'danceability': 0.657,
#   'energy': 0.577,
#   'key': 2,
#   'loudness': -8.586,
#   'mode': 0,
#   'speechiness': 0.0341,
#   'acousticness': 0.393,
#   'instrumentalness': 0.0291,
#   'liveness': 0.105,
#   'valence': 0.434,
#   'tempo': 135.558,
#   'type': 'audio_features',
#   'id': '7dUdMZqfGSIt0ZkmTOgRLA',
#   'uri': 'spotify:track:7dUdMZqfGSIt0ZkmTOgRLA',
#   'track_href': 'https://api.spotify.com/v1/tracks/7dUdMZqfGSIt0ZkmTOgRLA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7dUdMZqfGSIt0ZkmTOgRLA',
#   'duration_ms': 191480,
#   'time_signature': 4},
#  {'danceability': 0.541,
#   'energy': 0.503,
#   'key': 0,
#   'loudness': -10.649,
#   'mode': 1,
#   'speechiness': 0.13,
#   'acousticness': 0.609,
#   'instrumentalness': 0,
#   'liveness': 0.691,
#   'valence': 0.755,
#   'tempo': 76.662,
#   'type': 'audio_features',
#   'id': '3twxRT6f42UpjE2xUVcdG3',
#   'uri': 'spotify:track:3twxRT6f42UpjE2xUVcdG3',
#   'track_href': 'https://api.spotify.com/v1/tracks/3twxRT6f42UpjE2xUVcdG3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3twxRT6f42UpjE2xUVcdG3',
#   'duration_ms': 159103,
#   'time_signature': 4},
#  {'danceability': 0.176,
#   'energy': 0.106,
#   'key': 2,
#   'loudness': -25.103,
#   'mode': 0,
#   'speechiness': 0.0459,
#   'acousticness': 0.946,
#   'instrumentalness': 0.598,
#   'liveness': 0.0858,
#   'valence': 0.111,
#   'tempo': 107.057,
#   'type': 'audio_features',
#   'id': '6O7Et1ArYoS9nOKwRjK3Oq',
#   'uri': 'spotify:track:6O7Et1ArYoS9nOKwRjK3Oq',
#   'track_href': 'https://api.spotify.com/v1/tracks/6O7Et1ArYoS9nOKwRjK3Oq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6O7Et1ArYoS9nOKwRjK3Oq',
#   'duration_ms': 211760,
#   'time_signature': 3},
#  {'danceability': 0.759,
#   'energy': 0.792,
#   'key': 1,
#   'loudness': -3.259,
#   'mode': 1,
#   'speechiness': 0.177,
#   'acousticness': 0.0306,
#   'instrumentalness': 0,
#   'liveness': 0.142,
#   'valence': 0.542,
#   'tempo': 130.119,
#   'type': 'audio_features',
#   'id': '2C4XQsZFeze4yMatFzY9M2',
#   'uri': 'spotify:track:2C4XQsZFeze4yMatFzY9M2',
#   'track_href': 'https://api.spotify.com/v1/tracks/2C4XQsZFeze4yMatFzY9M2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2C4XQsZFeze4yMatFzY9M2',
#   'duration_ms': 236520,
#   'time_signature': 4},
#  {'danceability': 0.784,
#   'energy': 0.608,
#   'key': 7,
#   'loudness': -5.885,
#   'mode': 1,
#   'speechiness': 0.245,
#   'acousticness': 0.167,
#   'instrumentalness': 0,
#   'liveness': 0.0871,
#   'valence': 0.382,
#   'tempo': 90.713,
#   'type': 'audio_features',
#   'id': '1GOuHB20lqVyxv3GdxovPY',
#   'uri': 'spotify:track:1GOuHB20lqVyxv3GdxovPY',
#   'track_href': 'https://api.spotify.com/v1/tracks/1GOuHB20lqVyxv3GdxovPY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1GOuHB20lqVyxv3GdxovPY',
#   'duration_ms': 211685,
#   'time_signature': 4},
#  {'danceability': 0.535,
#   'energy': 0.266,
#   'key': 4,
#   'loudness': -9.97,
#   'mode': 1,
#   'speechiness': 0.03,
#   'acousticness': 0.76,
#   'instrumentalness': 4.91e-05,
#   'liveness': 0.243,
#   'valence': 0.221,
#   'tempo': 83.177,
#   'type': 'audio_features',
#   'id': '3yju5QYFjndmGvaG2wVvPv',
#   'uri': 'spotify:track:3yju5QYFjndmGvaG2wVvPv',
#   'track_href': 'https://api.spotify.com/v1/tracks/3yju5QYFjndmGvaG2wVvPv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3yju5QYFjndmGvaG2wVvPv',
#   'duration_ms': 255027,
#   'time_signature': 3},
#  {'danceability': 0.58,
#   'energy': 0.71,
#   'key': 7,
#   'loudness': -5.902,
#   'mode': 0,
#   'speechiness': 0.0342,
#   'acousticness': 0.00135,
#   'instrumentalness': 4.97e-06,
#   'liveness': 0.309,
#   'valence': 0.564,
#   'tempo': 116.007,
#   'type': 'audio_features',
#   'id': '1dbLmUsZJFTbHCsAGE4x2D',
#   'uri': 'spotify:track:1dbLmUsZJFTbHCsAGE4x2D',
#   'track_href': 'https://api.spotify.com/v1/tracks/1dbLmUsZJFTbHCsAGE4x2D',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1dbLmUsZJFTbHCsAGE4x2D',
#   'duration_ms': 233733,
#   'time_signature': 4},
#  {'danceability': 0.556,
#   'energy': 0.501,
#   'key': 1,
#   'loudness': -11.429,
#   'mode': 1,
#   'speechiness': 0.371,
#   'acousticness': 0.123,
#   'instrumentalness': 0.000106,
#   'liveness': 0.97,
#   'valence': 0.382,
#   'tempo': 104.356,
#   'type': 'audio_features',
#   'id': '6wwPtKxaMEbQYc6atQmhTE',
#   'uri': 'spotify:track:6wwPtKxaMEbQYc6atQmhTE',
#   'track_href': 'https://api.spotify.com/v1/tracks/6wwPtKxaMEbQYc6atQmhTE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6wwPtKxaMEbQYc6atQmhTE',
#   'duration_ms': 105827,
#   'time_signature': 4},
#  {'danceability': 0.218,
#   'energy': 0.19,
#   'key': 7,
#   'loudness': -20.281,
#   'mode': 1,
#   'speechiness': 0.0355,
#   'acousticness': 0.772,
#   'instrumentalness': 0.749,
#   'liveness': 0.133,
#   'valence': 0.0695,
#   'tempo': 78.962,
#   'type': 'audio_features',
#   'id': '4yRMcsWVWCYGQPj5am1UCP',
#   'uri': 'spotify:track:4yRMcsWVWCYGQPj5am1UCP',
#   'track_href': 'https://api.spotify.com/v1/tracks/4yRMcsWVWCYGQPj5am1UCP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4yRMcsWVWCYGQPj5am1UCP',
#   'duration_ms': 222773,
#   'time_signature': 3},
#  {'danceability': 0.545,
#   'energy': 0.879,
#   'key': 2,
#   'loudness': -3.291,
#   'mode': 1,
#   'speechiness': 0.401,
#   'acousticness': 0.738,
#   'instrumentalness': 0,
#   'liveness': 0.184,
#   'valence': 0.814,
#   'tempo': 64.848,
#   'type': 'audio_features',
#   'id': '4JMvnscEzgZNXzppm8V0Qs',
#   'uri': 'spotify:track:4JMvnscEzgZNXzppm8V0Qs',
#   'track_href': 'https://api.spotify.com/v1/tracks/4JMvnscEzgZNXzppm8V0Qs',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4JMvnscEzgZNXzppm8V0Qs',
#   'duration_ms': 127173,
#   'time_signature': 3},
#  {'danceability': 0.466,
#   'energy': 0.443,
#   'key': 1,
#   'loudness': -10.584,
#   'mode': 0,
#   'speechiness': 0.0975,
#   'acousticness': 0.106,
#   'instrumentalness': 0.612,
#   'liveness': 0.159,
#   'valence': 0.116,
#   'tempo': 100.762,
#   'type': 'audio_features',
#   'id': '3nHbQNMuGuEtIVhPGVfFbF',
#   'uri': 'spotify:track:3nHbQNMuGuEtIVhPGVfFbF',
#   'track_href': 'https://api.spotify.com/v1/tracks/3nHbQNMuGuEtIVhPGVfFbF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3nHbQNMuGuEtIVhPGVfFbF',
#   'duration_ms': 199467,
#   'time_signature': 4},
#  {'danceability': 0.104,
#   'energy': 0.1,
#   'key': 9,
#   'loudness': -21.45,
#   'mode': 1,
#   'speechiness': 0.0414,
#   'acousticness': 0.948,
#   'instrumentalness': 0.784,
#   'liveness': 0.0881,
#   'valence': 0.0375,
#   'tempo': 91.484,
#   'type': 'audio_features',
#   'id': '3zQN4zs4BiEnSI3sh2PZwa',
#   'uri': 'spotify:track:3zQN4zs4BiEnSI3sh2PZwa',
#   'track_href': 'https://api.spotify.com/v1/tracks/3zQN4zs4BiEnSI3sh2PZwa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3zQN4zs4BiEnSI3sh2PZwa',
#   'duration_ms': 297600,
#   'time_signature': 4},
#  {'danceability': 0.484,
#   'energy': 0.177,
#   'key': 4,
#   'loudness': -11.536,
#   'mode': 1,
#   'speechiness': 0.0428,
#   'acousticness': 0.752,
#   'instrumentalness': 1.51e-05,
#   'liveness': 0.115,
#   'valence': 0.279,
#   'tempo': 102.869,
#   'type': 'audio_features',
#   'id': '5EVXcYg6G8at6IDQbi9M2F',
#   'uri': 'spotify:track:5EVXcYg6G8at6IDQbi9M2F',
#   'track_href': 'https://api.spotify.com/v1/tracks/5EVXcYg6G8at6IDQbi9M2F',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5EVXcYg6G8at6IDQbi9M2F',
#   'duration_ms': 220440,
#   'time_signature': 4},
#  {'danceability': 0.601,
#   'energy': 0.773,
#   'key': 0,
#   'loudness': -2.562,
#   'mode': 1,
#   'speechiness': 0.0273,
#   'acousticness': 0.517,
#   'instrumentalness': 0,
#   'liveness': 0.39,
#   'valence': 0.762,
#   'tempo': 140.163,
#   'type': 'audio_features',
#   'id': '7vcryRa5cl0iJ4Bif3dKWU',
#   'uri': 'spotify:track:7vcryRa5cl0iJ4Bif3dKWU',
#   'track_href': 'https://api.spotify.com/v1/tracks/7vcryRa5cl0iJ4Bif3dKWU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7vcryRa5cl0iJ4Bif3dKWU',
#   'duration_ms': 190667,
#   'time_signature': 4},
#  {'danceability': 0.782,
#   'energy': 0.756,
#   'key': 2,
#   'loudness': -4.238,
#   'mode': 1,
#   'speechiness': 0.0715,
#   'acousticness': 0.571,
#   'instrumentalness': 0,
#   'liveness': 0.137,
#   'valence': 0.879,
#   'tempo': 102.98,
#   'type': 'audio_features',
#   'id': '3943Xwoj2F9TfuLgHDYM8J',
#   'uri': 'spotify:track:3943Xwoj2F9TfuLgHDYM8J',
#   'track_href': 'https://api.spotify.com/v1/tracks/3943Xwoj2F9TfuLgHDYM8J',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3943Xwoj2F9TfuLgHDYM8J',
#   'duration_ms': 143173,
#   'time_signature': 4},
#  {'danceability': 0.252,
#   'energy': 0.369,
#   'key': 7,
#   'loudness': -15.126,
#   'mode': 1,
#   'speechiness': 0.0439,
#   'acousticness': 0.665,
#   'instrumentalness': 0.901,
#   'liveness': 0.502,
#   'valence': 0.282,
#   'tempo': 81.246,
#   'type': 'audio_features',
#   'id': '341LEcA134Ms2ri6WhJUwV',
#   'uri': 'spotify:track:341LEcA134Ms2ri6WhJUwV',
#   'track_href': 'https://api.spotify.com/v1/tracks/341LEcA134Ms2ri6WhJUwV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/341LEcA134Ms2ri6WhJUwV',
#   'duration_ms': 373573,
#   'time_signature': 4},
#  {'danceability': 0.653,
#   'energy': 0.71,
#   'key': 8,
#   'loudness': -8.444,
#   'mode': 1,
#   'speechiness': 0.0555,
#   'acousticness': 0.33,
#   'instrumentalness': 0,
#   'liveness': 0.143,
#   'valence': 0.41,
#   'tempo': 122.04,
#   'type': 'audio_features',
#   'id': '3I8MbKRkS2IBDuslhCS3iT',
#   'uri': 'spotify:track:3I8MbKRkS2IBDuslhCS3iT',
#   'track_href': 'https://api.spotify.com/v1/tracks/3I8MbKRkS2IBDuslhCS3iT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3I8MbKRkS2IBDuslhCS3iT',
#   'duration_ms': 238053,
#   'time_signature': 4},
#  {'danceability': 0.537,
#   'energy': 0.938,
#   'key': 7,
#   'loudness': -5.951,
#   'mode': 1,
#   'speechiness': 0.0504,
#   'acousticness': 0.0176,
#   'instrumentalness': 3.08e-05,
#   'liveness': 0.367,
#   'valence': 0.518,
#   'tempo': 105.796,
#   'type': 'audio_features',
#   'id': '1Wdhwm3TtIuZvohSZNpZwP',
#   'uri': 'spotify:track:1Wdhwm3TtIuZvohSZNpZwP',
#   'track_href': 'https://api.spotify.com/v1/tracks/1Wdhwm3TtIuZvohSZNpZwP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Wdhwm3TtIuZvohSZNpZwP',
#   'duration_ms': 247440,
#   'time_signature': 4},
#  {'danceability': 0.76,
#   'energy': 0.744,
#   'key': 2,
#   'loudness': -4.48,
#   'mode': 1,
#   'speechiness': 0.0791,
#   'acousticness': 0.485,
#   'instrumentalness': 3.67e-06,
#   'liveness': 0.0987,
#   'valence': 0.807,
#   'tempo': 102.912,
#   'type': 'audio_features',
#   'id': '4kBbLU8WnCWknsYXHPCsv2',
#   'uri': 'spotify:track:4kBbLU8WnCWknsYXHPCsv2',
#   'track_href': 'https://api.spotify.com/v1/tracks/4kBbLU8WnCWknsYXHPCsv2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4kBbLU8WnCWknsYXHPCsv2',
#   'duration_ms': 145307,
#   'time_signature': 4},
#  {'danceability': 0.503,
#   'energy': 0.683,
#   'key': 1,
#   'loudness': -7.104,
#   'mode': 1,
#   'speechiness': 0.17,
#   'acousticness': 0.654,
#   'instrumentalness': 4.83e-05,
#   'liveness': 0.142,
#   'valence': 0.775,
#   'tempo': 173.214,
#   'type': 'audio_features',
#   'id': '3yXknYHbkcSca92PSSVniX',
#   'uri': 'spotify:track:3yXknYHbkcSca92PSSVniX',
#   'track_href': 'https://api.spotify.com/v1/tracks/3yXknYHbkcSca92PSSVniX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3yXknYHbkcSca92PSSVniX',
#   'duration_ms': 283733,
#   'time_signature': 4},
#  {'danceability': 0.816,
#   'energy': 0.892,
#   'key': 1,
#   'loudness': -4.999,
#   'mode': 1,
#   'speechiness': 0.264,
#   'acousticness': 0.333,
#   'instrumentalness': 0.000298,
#   'liveness': 0.305,
#   'valence': 0.854,
#   'tempo': 126.165,
#   'type': 'audio_features',
#   'id': '5OGzWbdJVqlHGIVqqZyoPX',
#   'uri': 'spotify:track:5OGzWbdJVqlHGIVqqZyoPX',
#   'track_href': 'https://api.spotify.com/v1/tracks/5OGzWbdJVqlHGIVqqZyoPX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5OGzWbdJVqlHGIVqqZyoPX',
#   'duration_ms': 203827,
#   'time_signature': 4},
#  {'danceability': 0.711,
#   'energy': 0.748,
#   'key': 11,
#   'loudness': -4.198,
#   'mode': 0,
#   'speechiness': 0.391,
#   'acousticness': 0.225,
#   'instrumentalness': 0,
#   'liveness': 0.145,
#   'valence': 0.961,
#   'tempo': 132.022,
#   'type': 'audio_features',
#   'id': '44YNLnTujChFsBmuVts4me',
#   'uri': 'spotify:track:44YNLnTujChFsBmuVts4me',
#   'track_href': 'https://api.spotify.com/v1/tracks/44YNLnTujChFsBmuVts4me',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/44YNLnTujChFsBmuVts4me',
#   'duration_ms': 118600,
#   'time_signature': 5},
#  {'danceability': 0.735,
#   'energy': 0.934,
#   'key': 9,
#   'loudness': -5.871,
#   'mode': 0,
#   'speechiness': 0.0446,
#   'acousticness': 0.0409,
#   'instrumentalness': 0.011,
#   'liveness': 0.125,
#   'valence': 0.535,
#   'tempo': 119.998,
#   'type': 'audio_features',
#   'id': '06M6ANp2yXdhpGssKPhT69',
#   'uri': 'spotify:track:06M6ANp2yXdhpGssKPhT69',
#   'track_href': 'https://api.spotify.com/v1/tracks/06M6ANp2yXdhpGssKPhT69',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/06M6ANp2yXdhpGssKPhT69',
#   'duration_ms': 229667,
#   'time_signature': 4},
#  {'danceability': 0.531,
#   'energy': 0.289,
#   'key': 7,
#   'loudness': -16.255,
#   'mode': 0,
#   'speechiness': 0.0316,
#   'acousticness': 0.819,
#   'instrumentalness': 0.721,
#   'liveness': 0.191,
#   'valence': 0.15,
#   'tempo': 104.233,
#   'type': 'audio_features',
#   'id': '18gj6WTWnjJA5s7FSTVQwj',
#   'uri': 'spotify:track:18gj6WTWnjJA5s7FSTVQwj',
#   'track_href': 'https://api.spotify.com/v1/tracks/18gj6WTWnjJA5s7FSTVQwj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/18gj6WTWnjJA5s7FSTVQwj',
#   'duration_ms': 184440,
#   'time_signature': 4},
#  {'danceability': 0.42,
#   'energy': 0.936,
#   'key': 11,
#   'loudness': -4.31,
#   'mode': 1,
#   'speechiness': 0.0433,
#   'acousticness': 0.000264,
#   'instrumentalness': 0.175,
#   'liveness': 0.101,
#   'valence': 0.711,
#   'tempo': 153.955,
#   'type': 'audio_features',
#   'id': '3EVgZBKWXY6xOtS8mrhW1C',
#   'uri': 'spotify:track:3EVgZBKWXY6xOtS8mrhW1C',
#   'track_href': 'https://api.spotify.com/v1/tracks/3EVgZBKWXY6xOtS8mrhW1C',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3EVgZBKWXY6xOtS8mrhW1C',
#   'duration_ms': 226547,
#   'time_signature': 4},
#  {'danceability': 0.358,
#   'energy': 0.886,
#   'key': 5,
#   'loudness': -8.325,
#   'mode': 0,
#   'speechiness': 0.0734,
#   'acousticness': 0.547,
#   'instrumentalness': 0,
#   'liveness': 0.795,
#   'valence': 0.744,
#   'tempo': 167.415,
#   'type': 'audio_features',
#   'id': '5w3rCESBlHOV2CLYUONlDO',
#   'uri': 'spotify:track:5w3rCESBlHOV2CLYUONlDO',
#   'track_href': 'https://api.spotify.com/v1/tracks/5w3rCESBlHOV2CLYUONlDO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5w3rCESBlHOV2CLYUONlDO',
#   'duration_ms': 178701,
#   'time_signature': 4},
#  {'danceability': 0.814,
#   'energy': 0.693,
#   'key': 11,
#   'loudness': -7.179,
#   'mode': 0,
#   'speechiness': 0.036,
#   'acousticness': 0.488,
#   'instrumentalness': 0.19,
#   'liveness': 0.108,
#   'valence': 0.773,
#   'tempo': 125.006,
#   'type': 'audio_features',
#   'id': '67h3AeLwglIaguXt95F0jQ',
#   'uri': 'spotify:track:67h3AeLwglIaguXt95F0jQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/67h3AeLwglIaguXt95F0jQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/67h3AeLwglIaguXt95F0jQ',
#   'duration_ms': 217800,
#   'time_signature': 4},
#  {'danceability': 0.604,
#   'energy': 0.738,
#   'key': 10,
#   'loudness': -8.64,
#   'mode': 1,
#   'speechiness': 0.0296,
#   'acousticness': 0.00546,
#   'instrumentalness': 0.00253,
#   'liveness': 0.107,
#   'valence': 0.797,
#   'tempo': 115.099,
#   'type': 'audio_features',
#   'id': '4WKGfdb5aYHv4srH7zuclB',
#   'uri': 'spotify:track:4WKGfdb5aYHv4srH7zuclB',
#   'track_href': 'https://api.spotify.com/v1/tracks/4WKGfdb5aYHv4srH7zuclB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4WKGfdb5aYHv4srH7zuclB',
#   'duration_ms': 247920,
#   'time_signature': 4},
#  {'danceability': 0.838,
#   'energy': 0.793,
#   'key': 6,
#   'loudness': -8.924,
#   'mode': 1,
#   'speechiness': 0.284,
#   'acousticness': 0.212,
#   'instrumentalness': 2.19e-05,
#   'liveness': 0.21,
#   'valence': 0.73,
#   'tempo': 97.685,
#   'type': 'audio_features',
#   'id': '2XKmD2Fy4rVWzL7CFDpd2s',
#   'uri': 'spotify:track:2XKmD2Fy4rVWzL7CFDpd2s',
#   'track_href': 'https://api.spotify.com/v1/tracks/2XKmD2Fy4rVWzL7CFDpd2s',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2XKmD2Fy4rVWzL7CFDpd2s',
#   'duration_ms': 447680,
#   'time_signature': 4},
#  {'danceability': 0.339,
#   'energy': 0.896,
#   'key': 10,
#   'loudness': -6.769,
#   'mode': 0,
#   'speechiness': 0.118,
#   'acousticness': 0.0527,
#   'instrumentalness': 0.221,
#   'liveness': 0.0483,
#   'valence': 0.104,
#   'tempo': 91.971,
#   'type': 'audio_features',
#   'id': '2546X1mmMxfa9ZtFfVk1E0',
#   'uri': 'spotify:track:2546X1mmMxfa9ZtFfVk1E0',
#   'track_href': 'https://api.spotify.com/v1/tracks/2546X1mmMxfa9ZtFfVk1E0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2546X1mmMxfa9ZtFfVk1E0',
#   'duration_ms': 351093,
#   'time_signature': 4},
#  {'danceability': 0.288,
#   'energy': 0.938,
#   'key': 5,
#   'loudness': -6.149,
#   'mode': 1,
#   'speechiness': 0.207,
#   'acousticness': 0.00114,
#   'instrumentalness': 0.0194,
#   'liveness': 0.112,
#   'valence': 0.0568,
#   'tempo': 152.157,
#   'type': 'audio_features',
#   'id': '0X01f4iKEmUgco8ma24Wng',
#   'uri': 'spotify:track:0X01f4iKEmUgco8ma24Wng',
#   'track_href': 'https://api.spotify.com/v1/tracks/0X01f4iKEmUgco8ma24Wng',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0X01f4iKEmUgco8ma24Wng',
#   'duration_ms': 123867,
#   'time_signature': 4},
#  {'danceability': 0.663,
#   'energy': 0.618,
#   'key': 1,
#   'loudness': -4.995,
#   'mode': 1,
#   'speechiness': 0.474,
#   'acousticness': 0.0236,
#   'instrumentalness': 0,
#   'liveness': 0.0864,
#   'valence': 0.767,
#   'tempo': 76.743,
#   'type': 'audio_features',
#   'id': '1q1czFTQvKFTlNGXO4qLUj',
#   'uri': 'spotify:track:1q1czFTQvKFTlNGXO4qLUj',
#   'track_href': 'https://api.spotify.com/v1/tracks/1q1czFTQvKFTlNGXO4qLUj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1q1czFTQvKFTlNGXO4qLUj',
#   'duration_ms': 241387,
#   'time_signature': 4},
#  {'danceability': 0.514,
#   'energy': 0.78,
#   'key': 10,
#   'loudness': -6.491,
#   'mode': 0,
#   'speechiness': 0.198,
#   'acousticness': 0.127,
#   'instrumentalness': 0,
#   'liveness': 0.349,
#   'valence': 0.331,
#   'tempo': 75.549,
#   'type': 'audio_features',
#   'id': '6AHNkRbVzkh95xilnYzDT7',
#   'uri': 'spotify:track:6AHNkRbVzkh95xilnYzDT7',
#   'track_href': 'https://api.spotify.com/v1/tracks/6AHNkRbVzkh95xilnYzDT7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6AHNkRbVzkh95xilnYzDT7',
#   'duration_ms': 191200,
#   'time_signature': 4},
#  {'danceability': 0.655,
#   'energy': 0.0645,
#   'key': 4,
#   'loudness': -14.765,
#   'mode': 1,
#   'speechiness': 0.0429,
#   'acousticness': 0.854,
#   'instrumentalness': 1.11e-05,
#   'liveness': 0.107,
#   'valence': 0.278,
#   'tempo': 129.399,
#   'type': 'audio_features',
#   'id': '6Wo5YxkdXgwzKQZbDg2r17',
#   'uri': 'spotify:track:6Wo5YxkdXgwzKQZbDg2r17',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Wo5YxkdXgwzKQZbDg2r17',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Wo5YxkdXgwzKQZbDg2r17',
#   'duration_ms': 248053,
#   'time_signature': 4},
#  {'danceability': 0.724,
#   'energy': 0.827,
#   'key': 11,
#   'loudness': -4.211,
#   'mode': 0,
#   'speechiness': 0.129,
#   'acousticness': 0.0457,
#   'instrumentalness': 0,
#   'liveness': 0.0848,
#   'valence': 0.2,
#   'tempo': 144.973,
#   'type': 'audio_features',
#   'id': '6pVSAHKEKOWxDcfr8haIGe',
#   'uri': 'spotify:track:6pVSAHKEKOWxDcfr8haIGe',
#   'track_href': 'https://api.spotify.com/v1/tracks/6pVSAHKEKOWxDcfr8haIGe',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6pVSAHKEKOWxDcfr8haIGe',
#   'duration_ms': 251707,
#   'time_signature': 4},
#  {'danceability': 0.58,
#   'energy': 0.732,
#   'key': 2,
#   'loudness': -4.879,
#   'mode': 1,
#   'speechiness': 0.121,
#   'acousticness': 0.6,
#   'instrumentalness': 0,
#   'liveness': 0.29,
#   'valence': 0.872,
#   'tempo': 97.252,
#   'type': 'audio_features',
#   'id': '0WcZxRUxHKp07RtI4vnBFK',
#   'uri': 'spotify:track:0WcZxRUxHKp07RtI4vnBFK',
#   'track_href': 'https://api.spotify.com/v1/tracks/0WcZxRUxHKp07RtI4vnBFK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0WcZxRUxHKp07RtI4vnBFK',
#   'duration_ms': 144600,
#   'time_signature': 4},
#  {'danceability': 0.774,
#   'energy': 0.628,
#   'key': 3,
#   'loudness': -3.995,
#   'mode': 1,
#   'speechiness': 0.0436,
#   'acousticness': 0.536,
#   'instrumentalness': 6.7e-05,
#   'liveness': 0.196,
#   'valence': 0.696,
#   'tempo': 90.013,
#   'type': 'audio_features',
#   'id': '0o4ETDFkxzmbYRGhyTdhNS',
#   'uri': 'spotify:track:0o4ETDFkxzmbYRGhyTdhNS',
#   'track_href': 'https://api.spotify.com/v1/tracks/0o4ETDFkxzmbYRGhyTdhNS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0o4ETDFkxzmbYRGhyTdhNS',
#   'duration_ms': 206907,
#   'time_signature': 4},
#  {'danceability': 0.695,
#   'energy': 0.653,
#   'key': 6,
#   'loudness': -4.478,
#   'mode': 0,
#   'speechiness': 0.0301,
#   'acousticness': 0.116,
#   'instrumentalness': 0.000216,
#   'liveness': 0.161,
#   'valence': 0.545,
#   'tempo': 110.007,
#   'type': 'audio_features',
#   'id': '4DvfGBOSlrzC9QeGEeQGxv',
#   'uri': 'spotify:track:4DvfGBOSlrzC9QeGEeQGxv',
#   'track_href': 'https://api.spotify.com/v1/tracks/4DvfGBOSlrzC9QeGEeQGxv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4DvfGBOSlrzC9QeGEeQGxv',
#   'duration_ms': 246413,
#   'time_signature': 4},
#  {'danceability': 0.831,
#   'energy': 0.45,
#   'key': 11,
#   'loudness': -6.611,
#   'mode': 0,
#   'speechiness': 0.0581,
#   'acousticness': 0.00211,
#   'instrumentalness': 0.864,
#   'liveness': 0.113,
#   'valence': 0.767,
#   'tempo': 102.986,
#   'type': 'audio_features',
#   'id': '7j2fN0rZh83ZbPbuNJH6pF',
#   'uri': 'spotify:track:7j2fN0rZh83ZbPbuNJH6pF',
#   'track_href': 'https://api.spotify.com/v1/tracks/7j2fN0rZh83ZbPbuNJH6pF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7j2fN0rZh83ZbPbuNJH6pF',
#   'duration_ms': 143267,
#   'time_signature': 4},
#  {'danceability': 0.153,
#   'energy': 0.0227,
#   'key': 7,
#   'loudness': -28.042,
#   'mode': 1,
#   'speechiness': 0.0367,
#   'acousticness': 0.977,
#   'instrumentalness': 0.934,
#   'liveness': 0.0875,
#   'valence': 0.0839,
#   'tempo': 84.294,
#   'type': 'audio_features',
#   'id': '4emfQeHkPHPZjMTmJtQflg',
#   'uri': 'spotify:track:4emfQeHkPHPZjMTmJtQflg',
#   'track_href': 'https://api.spotify.com/v1/tracks/4emfQeHkPHPZjMTmJtQflg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4emfQeHkPHPZjMTmJtQflg',
#   'duration_ms': 386933,
#   'time_signature': 3},
#  {'danceability': 0.507,
#   'energy': 0.662,
#   'key': 0,
#   'loudness': -6.458,
#   'mode': 1,
#   'speechiness': 0.0278,
#   'acousticness': 0.0148,
#   'instrumentalness': 0.000362,
#   'liveness': 0.311,
#   'valence': 0.153,
#   'tempo': 103.435,
#   'type': 'audio_features',
#   'id': '22q0Q9kJrricJ75sIp7gTy',
#   'uri': 'spotify:track:22q0Q9kJrricJ75sIp7gTy',
#   'track_href': 'https://api.spotify.com/v1/tracks/22q0Q9kJrricJ75sIp7gTy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/22q0Q9kJrricJ75sIp7gTy',
#   'duration_ms': 232920,
#   'time_signature': 4},
#  {'danceability': 0.523,
#   'energy': 0.853,
#   'key': 4,
#   'loudness': -5.972,
#   'mode': 0,
#   'speechiness': 0.0267,
#   'acousticness': 0.00316,
#   'instrumentalness': 0.835,
#   'liveness': 0.245,
#   'valence': 0.515,
#   'tempo': 103.769,
#   'type': 'audio_features',
#   'id': '19OmsLCVYcEGoMgmbzZxPv',
#   'uri': 'spotify:track:19OmsLCVYcEGoMgmbzZxPv',
#   'track_href': 'https://api.spotify.com/v1/tracks/19OmsLCVYcEGoMgmbzZxPv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/19OmsLCVYcEGoMgmbzZxPv',
#   'duration_ms': 215813,
#   'time_signature': 4},
#  {'danceability': 0.359,
#   'energy': 0.173,
#   'key': 1,
#   'loudness': -21.205,
#   'mode': 0,
#   'speechiness': 0.0581,
#   'acousticness': 0.742,
#   'instrumentalness': 0.959,
#   'liveness': 0.5,
#   'valence': 0.0857,
#   'tempo': 118.277,
#   'type': 'audio_features',
#   'id': '1rykvAlTc3RqvyDrRztlAI',
#   'uri': 'spotify:track:1rykvAlTc3RqvyDrRztlAI',
#   'track_href': 'https://api.spotify.com/v1/tracks/1rykvAlTc3RqvyDrRztlAI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1rykvAlTc3RqvyDrRztlAI',
#   'duration_ms': 170867,
#   'time_signature': 4},
#  {'danceability': 0.431,
#   'energy': 0.431,
#   'key': 6,
#   'loudness': -9.857,
#   'mode': 1,
#   'speechiness': 0.0313,
#   'acousticness': 0.377,
#   'instrumentalness': 0.000121,
#   'liveness': 0.294,
#   'valence': 0.587,
#   'tempo': 97.623,
#   'type': 'audio_features',
#   'id': '4YXlJiIXYad3yWAYqC5zOa',
#   'uri': 'spotify:track:4YXlJiIXYad3yWAYqC5zOa',
#   'track_href': 'https://api.spotify.com/v1/tracks/4YXlJiIXYad3yWAYqC5zOa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4YXlJiIXYad3yWAYqC5zOa',
#   'duration_ms': 249568,
#   'time_signature': 3},
#  {'danceability': 0.154,
#   'energy': 0.0612,
#   'key': 5,
#   'loudness': -21.292,
#   'mode': 1,
#   'speechiness': 0.0404,
#   'acousticness': 0.947,
#   'instrumentalness': 0.711,
#   'liveness': 0.0903,
#   'valence': 0.0397,
#   'tempo': 77.182,
#   'type': 'audio_features',
#   'id': '5BvR4B2flWZ8Mh4fBgzJDf',
#   'uri': 'spotify:track:5BvR4B2flWZ8Mh4fBgzJDf',
#   'track_href': 'https://api.spotify.com/v1/tracks/5BvR4B2flWZ8Mh4fBgzJDf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5BvR4B2flWZ8Mh4fBgzJDf',
#   'duration_ms': 428800,
#   'time_signature': 4},
#  {'danceability': 0.806,
#   'energy': 0.84,
#   'key': 5,
#   'loudness': -1.941,
#   'mode': 1,
#   'speechiness': 0.104,
#   'acousticness': 0.541,
#   'instrumentalness': 0,
#   'liveness': 0.193,
#   'valence': 0.964,
#   'tempo': 112.815,
#   'type': 'audio_features',
#   'id': '4g83J52bPalyuNU9Y1Kuq9',
#   'uri': 'spotify:track:4g83J52bPalyuNU9Y1Kuq9',
#   'track_href': 'https://api.spotify.com/v1/tracks/4g83J52bPalyuNU9Y1Kuq9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4g83J52bPalyuNU9Y1Kuq9',
#   'duration_ms': 132627,
#   'time_signature': 3},
#  {'danceability': 0.395,
#   'energy': 0.64,
#   'key': 5,
#   'loudness': -3.678,
#   'mode': 0,
#   'speechiness': 0.0792,
#   'acousticness': 0.271,
#   'instrumentalness': 0,
#   'liveness': 0.112,
#   'valence': 0.383,
#   'tempo': 174.228,
#   'type': 'audio_features',
#   'id': '7yGJcaSJgpgXamjmXBCb6j',
#   'uri': 'spotify:track:7yGJcaSJgpgXamjmXBCb6j',
#   'track_href': 'https://api.spotify.com/v1/tracks/7yGJcaSJgpgXamjmXBCb6j',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7yGJcaSJgpgXamjmXBCb6j',
#   'duration_ms': 249613,
#   'time_signature': 4},
#  {'danceability': 0.385,
#   'energy': 0.677,
#   'key': 5,
#   'loudness': -9.421,
#   'mode': 0,
#   'speechiness': 0.167,
#   'acousticness': 0.581,
#   'instrumentalness': 1.63e-06,
#   'liveness': 0.352,
#   'valence': 0.634,
#   'tempo': 162.991,
#   'type': 'audio_features',
#   'id': '5Blc6gorvnXeldwIwz1Sfd',
#   'uri': 'spotify:track:5Blc6gorvnXeldwIwz1Sfd',
#   'track_href': 'https://api.spotify.com/v1/tracks/5Blc6gorvnXeldwIwz1Sfd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Blc6gorvnXeldwIwz1Sfd',
#   'duration_ms': 188964,
#   'time_signature': 4},
#  {'danceability': 0.802,
#   'energy': 0.951,
#   'key': 10,
#   'loudness': -3.933,
#   'mode': 0,
#   'speechiness': 0.189,
#   'acousticness': 0.482,
#   'instrumentalness': 0.00305,
#   'liveness': 0.319,
#   'valence': 0.695,
#   'tempo': 106.019,
#   'type': 'audio_features',
#   'id': '7gHkDNieGzYmyuC7E1Xbxw',
#   'uri': 'spotify:track:7gHkDNieGzYmyuC7E1Xbxw',
#   'track_href': 'https://api.spotify.com/v1/tracks/7gHkDNieGzYmyuC7E1Xbxw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7gHkDNieGzYmyuC7E1Xbxw',
#   'duration_ms': 191493,
#   'time_signature': 4},
#  {'danceability': 0.739,
#   'energy': 0.787,
#   'key': 11,
#   'loudness': -4.335,
#   'mode': 1,
#   'speechiness': 0.226,
#   'acousticness': 0.205,
#   'instrumentalness': 0,
#   'liveness': 0.256,
#   'valence': 0.603,
#   'tempo': 77.949,
#   'type': 'audio_features',
#   'id': '6TWgRy0WZEyPFIkYU505s8',
#   'uri': 'spotify:track:6TWgRy0WZEyPFIkYU505s8',
#   'track_href': 'https://api.spotify.com/v1/tracks/6TWgRy0WZEyPFIkYU505s8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6TWgRy0WZEyPFIkYU505s8',
#   'duration_ms': 246440,
#   'time_signature': 4},
#  {'danceability': 0.433,
#   'energy': 0.688,
#   'key': 0,
#   'loudness': -8.99,
#   'mode': 1,
#   'speechiness': 0.0684,
#   'acousticness': 0.709,
#   'instrumentalness': 0,
#   'liveness': 0.909,
#   'valence': 0.898,
#   'tempo': 172.26,
#   'type': 'audio_features',
#   'id': '4fV93JA79e1YCigVUV8mfe',
#   'uri': 'spotify:track:4fV93JA79e1YCigVUV8mfe',
#   'track_href': 'https://api.spotify.com/v1/tracks/4fV93JA79e1YCigVUV8mfe',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4fV93JA79e1YCigVUV8mfe',
#   'duration_ms': 104350,
#   'time_signature': 4},
#  {'danceability': 0.936,
#   'energy': 0.823,
#   'key': 5,
#   'loudness': -6.175,
#   'mode': 0,
#   'speechiness': 0.156,
#   'acousticness': 0.4,
#   'instrumentalness': 0.63,
#   'liveness': 0.408,
#   'valence': 0.913,
#   'tempo': 124.963,
#   'type': 'audio_features',
#   'id': '1CYSLNSMRvcsLbxIJuChZP',
#   'uri': 'spotify:track:1CYSLNSMRvcsLbxIJuChZP',
#   'track_href': 'https://api.spotify.com/v1/tracks/1CYSLNSMRvcsLbxIJuChZP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1CYSLNSMRvcsLbxIJuChZP',
#   'duration_ms': 245360,
#   'time_signature': 4},
#  {'danceability': 0.456,
#   'energy': 0.404,
#   'key': 2,
#   'loudness': -12.129,
#   'mode': 1,
#   'speechiness': 0.0496,
#   'acousticness': 0.716,
#   'instrumentalness': 0.000232,
#   'liveness': 0.92,
#   'valence': 0.542,
#   'tempo': 105.804,
#   'type': 'audio_features',
#   'id': '0sNKDMdRAGdI5C9afVMGEx',
#   'uri': 'spotify:track:0sNKDMdRAGdI5C9afVMGEx',
#   'track_href': 'https://api.spotify.com/v1/tracks/0sNKDMdRAGdI5C9afVMGEx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0sNKDMdRAGdI5C9afVMGEx',
#   'duration_ms': 383176,
#   'time_signature': 3},
#  {'danceability': 0.881,
#   'energy': 0.907,
#   'key': 2,
#   'loudness': -4.655,
#   'mode': 1,
#   'speechiness': 0.0895,
#   'acousticness': 0.654,
#   'instrumentalness': 0.00151,
#   'liveness': 0.0575,
#   'valence': 0.937,
#   'tempo': 125.027,
#   'type': 'audio_features',
#   'id': '16b7YDt2ys2zrXxr41pxt9',
#   'uri': 'spotify:track:16b7YDt2ys2zrXxr41pxt9',
#   'track_href': 'https://api.spotify.com/v1/tracks/16b7YDt2ys2zrXxr41pxt9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/16b7YDt2ys2zrXxr41pxt9',
#   'duration_ms': 300733,
#   'time_signature': 4},
#  {'danceability': 0.489,
#   'energy': 0.447,
#   'key': 7,
#   'loudness': -9.176,
#   'mode': 0,
#   'speechiness': 0.0336,
#   'acousticness': 0.329,
#   'instrumentalness': 0.00226,
#   'liveness': 0.105,
#   'valence': 0.14,
#   'tempo': 82.187,
#   'type': 'audio_features',
#   'id': '6Oexp3W6bv5LBzsS171iqN',
#   'uri': 'spotify:track:6Oexp3W6bv5LBzsS171iqN',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Oexp3W6bv5LBzsS171iqN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Oexp3W6bv5LBzsS171iqN',
#   'duration_ms': 231333,
#   'time_signature': 4},
#  {'danceability': 0.315,
#   'energy': 0.97,
#   'key': 8,
#   'loudness': -4.709,
#   'mode': 1,
#   'speechiness': 0.102,
#   'acousticness': 0.000696,
#   'instrumentalness': 0,
#   'liveness': 0.277,
#   'valence': 0.423,
#   'tempo': 178.068,
#   'type': 'audio_features',
#   'id': '25Sd73fleKUVPNqITPZkn1',
#   'uri': 'spotify:track:25Sd73fleKUVPNqITPZkn1',
#   'track_href': 'https://api.spotify.com/v1/tracks/25Sd73fleKUVPNqITPZkn1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/25Sd73fleKUVPNqITPZkn1',
#   'duration_ms': 202493,
#   'time_signature': 4},
#  {'danceability': 0.379,
#   'energy': 0.817,
#   'key': 7,
#   'loudness': -5.849,
#   'mode': 0,
#   'speechiness': 0.0459,
#   'acousticness': 0.000651,
#   'instrumentalness': 7.81e-06,
#   'liveness': 0.154,
#   'valence': 0.36,
#   'tempo': 158.045,
#   'type': 'audio_features',
#   'id': '26Aok9jFEw5YT1XAnyphbw',
#   'uri': 'spotify:track:26Aok9jFEw5YT1XAnyphbw',
#   'track_href': 'https://api.spotify.com/v1/tracks/26Aok9jFEw5YT1XAnyphbw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/26Aok9jFEw5YT1XAnyphbw',
#   'duration_ms': 242560,
#   'time_signature': 4},
#  {'danceability': 0.637,
#   'energy': 0.831,
#   'key': 1,
#   'loudness': -6.372,
#   'mode': 0,
#   'speechiness': 0.0298,
#   'acousticness': 0.223,
#   'instrumentalness': 0.402,
#   'liveness': 0.114,
#   'valence': 0.533,
#   'tempo': 90.008,
#   'type': 'audio_features',
#   'id': '6vkoFgpGHnQ9mwbZCY2yDh',
#   'uri': 'spotify:track:6vkoFgpGHnQ9mwbZCY2yDh',
#   'track_href': 'https://api.spotify.com/v1/tracks/6vkoFgpGHnQ9mwbZCY2yDh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6vkoFgpGHnQ9mwbZCY2yDh',
#   'duration_ms': 224587,
#   'time_signature': 4},
#  {'danceability': 0.642,
#   'energy': 0.56,
#   'key': 7,
#   'loudness': -15.123,
#   'mode': 1,
#   'speechiness': 0.0848,
#   'acousticness': 0.0541,
#   'instrumentalness': 0.752,
#   'liveness': 0.131,
#   'valence': 0.499,
#   'tempo': 130.003,
#   'type': 'audio_features',
#   'id': '6J9FgTr3z44Bw6ABeVL415',
#   'uri': 'spotify:track:6J9FgTr3z44Bw6ABeVL415',
#   'track_href': 'https://api.spotify.com/v1/tracks/6J9FgTr3z44Bw6ABeVL415',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6J9FgTr3z44Bw6ABeVL415',
#   'duration_ms': 222333,
#   'time_signature': 4},
#  {'danceability': 0.816,
#   'energy': 0.669,
#   'key': 10,
#   'loudness': -7.486,
#   'mode': 0,
#   'speechiness': 0.174,
#   'acousticness': 0.143,
#   'instrumentalness': 3.29e-05,
#   'liveness': 0.168,
#   'valence': 0.829,
#   'tempo': 107.732,
#   'type': 'audio_features',
#   'id': '1m1yWMD4yLUESsFOhEa6Ck',
#   'uri': 'spotify:track:1m1yWMD4yLUESsFOhEa6Ck',
#   'track_href': 'https://api.spotify.com/v1/tracks/1m1yWMD4yLUESsFOhEa6Ck',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1m1yWMD4yLUESsFOhEa6Ck',
#   'duration_ms': 316547,
#   'time_signature': 4},
#  {'danceability': 0.759,
#   'energy': 0.986,
#   'key': 5,
#   'loudness': -2.902,
#   'mode': 1,
#   'speechiness': 0.0385,
#   'acousticness': 0.456,
#   'instrumentalness': 7.35e-05,
#   'liveness': 0.124,
#   'valence': 0.922,
#   'tempo': 160.135,
#   'type': 'audio_features',
#   'id': '6o4uMkLbBrKS7a6vpNThpO',
#   'uri': 'spotify:track:6o4uMkLbBrKS7a6vpNThpO',
#   'track_href': 'https://api.spotify.com/v1/tracks/6o4uMkLbBrKS7a6vpNThpO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6o4uMkLbBrKS7a6vpNThpO',
#   'duration_ms': 158240,
#   'time_signature': 4},
#  {'danceability': 0.678,
#   'energy': 0.382,
#   'key': 2,
#   'loudness': -10.316,
#   'mode': 1,
#   'speechiness': 0.0422,
#   'acousticness': 0.741,
#   'instrumentalness': 0,
#   'liveness': 0.653,
#   'valence': 0.795,
#   'tempo': 120.643,
#   'type': 'audio_features',
#   'id': '74uwIzBc3pPWLin6ypQd32',
#   'uri': 'spotify:track:74uwIzBc3pPWLin6ypQd32',
#   'track_href': 'https://api.spotify.com/v1/tracks/74uwIzBc3pPWLin6ypQd32',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/74uwIzBc3pPWLin6ypQd32',
#   'duration_ms': 157989,
#   'time_signature': 4},
#  {'danceability': 0.385,
#   'energy': 0.906,
#   'key': 10,
#   'loudness': -4.406,
#   'mode': 1,
#   'speechiness': 0.0511,
#   'acousticness': 0.0019,
#   'instrumentalness': 0,
#   'liveness': 0.0625,
#   'valence': 0.703,
#   'tempo': 173.033,
#   'type': 'audio_features',
#   'id': '38W6hzEOvM50bUP6DaO9bP',
#   'uri': 'spotify:track:38W6hzEOvM50bUP6DaO9bP',
#   'track_href': 'https://api.spotify.com/v1/tracks/38W6hzEOvM50bUP6DaO9bP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/38W6hzEOvM50bUP6DaO9bP',
#   'duration_ms': 195173,
#   'time_signature': 4},
#  {'danceability': 0.469,
#   'energy': 0.407,
#   'key': 6,
#   'loudness': -10.897,
#   'mode': 1,
#   'speechiness': 0.0545,
#   'acousticness': 0.435,
#   'instrumentalness': 2.38e-06,
#   'liveness': 0.803,
#   'valence': 0.687,
#   'tempo': 103.358,
#   'type': 'audio_features',
#   'id': '7vn037pBVIJo916W1BCtE7',
#   'uri': 'spotify:track:7vn037pBVIJo916W1BCtE7',
#   'track_href': 'https://api.spotify.com/v1/tracks/7vn037pBVIJo916W1BCtE7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7vn037pBVIJo916W1BCtE7',
#   'duration_ms': 189243,
#   'time_signature': 3},
#  {'danceability': 0.851,
#   'energy': 0.79,
#   'key': 0,
#   'loudness': -4.641,
#   'mode': 0,
#   'speechiness': 0.0309,
#   'acousticness': 0.4,
#   'instrumentalness': 0.23,
#   'liveness': 0.123,
#   'valence': 0.889,
#   'tempo': 111.993,
#   'type': 'audio_features',
#   'id': '2yyQVP7siRFgduvFFPL6PC',
#   'uri': 'spotify:track:2yyQVP7siRFgduvFFPL6PC',
#   'track_href': 'https://api.spotify.com/v1/tracks/2yyQVP7siRFgduvFFPL6PC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2yyQVP7siRFgduvFFPL6PC',
#   'duration_ms': 251267,
#   'time_signature': 4},
#  {'danceability': 0.624,
#   'energy': 0.728,
#   'key': 0,
#   'loudness': -6.39,
#   'mode': 1,
#   'speechiness': 0.465,
#   'acousticness': 0.141,
#   'instrumentalness': 0,
#   'liveness': 0.106,
#   'valence': 0.599,
#   'tempo': 152.088,
#   'type': 'audio_features',
#   'id': '7mlkO7fkD1tJrxoqOMGzqF',
#   'uri': 'spotify:track:7mlkO7fkD1tJrxoqOMGzqF',
#   'track_href': 'https://api.spotify.com/v1/tracks/7mlkO7fkD1tJrxoqOMGzqF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7mlkO7fkD1tJrxoqOMGzqF',
#   'duration_ms': 227957,
#   'time_signature': 4},
#  {'danceability': 0.614,
#   'energy': 0.9,
#   'key': 11,
#   'loudness': -8.597,
#   'mode': 1,
#   'speechiness': 0.0492,
#   'acousticness': 0.00575,
#   'instrumentalness': 0.000105,
#   'liveness': 0.105,
#   'valence': 0.463,
#   'tempo': 126.477,
#   'type': 'audio_features',
#   'id': '4dWxZ4MghFNjpS0QJuR9eK',
#   'uri': 'spotify:track:4dWxZ4MghFNjpS0QJuR9eK',
#   'track_href': 'https://api.spotify.com/v1/tracks/4dWxZ4MghFNjpS0QJuR9eK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4dWxZ4MghFNjpS0QJuR9eK',
#   'duration_ms': 264533,
#   'time_signature': 4},
#  {'danceability': 0.85,
#   'energy': 0.697,
#   'key': 11,
#   'loudness': -9.859,
#   'mode': 0,
#   'speechiness': 0.407,
#   'acousticness': 0.183,
#   'instrumentalness': 0,
#   'liveness': 0.923,
#   'valence': 0.759,
#   'tempo': 118.007,
#   'type': 'audio_features',
#   'id': '64aTsM53REi7z5oCvep1EC',
#   'uri': 'spotify:track:64aTsM53REi7z5oCvep1EC',
#   'track_href': 'https://api.spotify.com/v1/tracks/64aTsM53REi7z5oCvep1EC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/64aTsM53REi7z5oCvep1EC',
#   'duration_ms': 251067,
#   'time_signature': 4},
#  {'danceability': 0.889,
#   'energy': 0.607,
#   'key': 0,
#   'loudness': -7.547,
#   'mode': 1,
#   'speechiness': 0.124,
#   'acousticness': 0.645,
#   'instrumentalness': 0.0625,
#   'liveness': 0.243,
#   'valence': 0.824,
#   'tempo': 97.43,
#   'type': 'audio_features',
#   'id': '1yd6mE2x3p13fcXPynCkKb',
#   'uri': 'spotify:track:1yd6mE2x3p13fcXPynCkKb',
#   'track_href': 'https://api.spotify.com/v1/tracks/1yd6mE2x3p13fcXPynCkKb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1yd6mE2x3p13fcXPynCkKb',
#   'duration_ms': 194800,
#   'time_signature': 4},
#  {'danceability': 0.639,
#   'energy': 0.725,
#   'key': 7,
#   'loudness': -5.309,
#   'mode': 1,
#   'speechiness': 0.0306,
#   'acousticness': 0.691,
#   'instrumentalness': 0.000144,
#   'liveness': 0.274,
#   'valence': 0.619,
#   'tempo': 136.956,
#   'type': 'audio_features',
#   'id': '5TphzFf2iv0l3VrFHN08kN',
#   'uri': 'spotify:track:5TphzFf2iv0l3VrFHN08kN',
#   'track_href': 'https://api.spotify.com/v1/tracks/5TphzFf2iv0l3VrFHN08kN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5TphzFf2iv0l3VrFHN08kN',
#   'duration_ms': 210440,
#   'time_signature': 4},
#  {'danceability': 0.766,
#   'energy': 0.75,
#   'key': 5,
#   'loudness': -5.056,
#   'mode': 1,
#   'speechiness': 0.0519,
#   'acousticness': 0.661,
#   'instrumentalness': 0.741,
#   'liveness': 0.121,
#   'valence': 0.833,
#   'tempo': 89.958,
#   'type': 'audio_features',
#   'id': '15nGklw2h1ocblZec7hETL',
#   'uri': 'spotify:track:15nGklw2h1ocblZec7hETL',
#   'track_href': 'https://api.spotify.com/v1/tracks/15nGklw2h1ocblZec7hETL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/15nGklw2h1ocblZec7hETL',
#   'duration_ms': 199987,
#   'time_signature': 4},
#  {'danceability': 0.7,
#   'energy': 0.642,
#   'key': 2,
#   'loudness': -8.673,
#   'mode': 0,
#   'speechiness': 0.317,
#   'acousticness': 0.0162,
#   'instrumentalness': 2.94e-06,
#   'liveness': 0.206,
#   'valence': 0.381,
#   'tempo': 149.989,
#   'type': 'audio_features',
#   'id': '5cYZm4KeDKM8Pw8z5XRKJt',
#   'uri': 'spotify:track:5cYZm4KeDKM8Pw8z5XRKJt',
#   'track_href': 'https://api.spotify.com/v1/tracks/5cYZm4KeDKM8Pw8z5XRKJt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5cYZm4KeDKM8Pw8z5XRKJt',
#   'duration_ms': 303000,
#   'time_signature': 4},
#  {'danceability': 0.683,
#   'energy': 0.854,
#   'key': 2,
#   'loudness': -3.915,
#   'mode': 1,
#   'speechiness': 0.196,
#   'acousticness': 0.0948,
#   'instrumentalness': 0,
#   'liveness': 0.267,
#   'valence': 0.131,
#   'tempo': 92.006,
#   'type': 'audio_features',
#   'id': '2sBHQfX9QxJwGcdutAj6Pj',
#   'uri': 'spotify:track:2sBHQfX9QxJwGcdutAj6Pj',
#   'track_href': 'https://api.spotify.com/v1/tracks/2sBHQfX9QxJwGcdutAj6Pj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2sBHQfX9QxJwGcdutAj6Pj',
#   'duration_ms': 189057,
#   'time_signature': 4},
#  {'danceability': 0.433,
#   'energy': 0.768,
#   'key': 9,
#   'loudness': -6.204,
#   'mode': 1,
#   'speechiness': 0.0808,
#   'acousticness': 0.000288,
#   'instrumentalness': 0.000574,
#   'liveness': 0.0822,
#   'valence': 0.671,
#   'tempo': 115.728,
#   'type': 'audio_features',
#   'id': '5H2B44TCS483P9e2gfdfMK',
#   'uri': 'spotify:track:5H2B44TCS483P9e2gfdfMK',
#   'track_href': 'https://api.spotify.com/v1/tracks/5H2B44TCS483P9e2gfdfMK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5H2B44TCS483P9e2gfdfMK',
#   'duration_ms': 315320,
#   'time_signature': 4},
#  {'danceability': 0.768,
#   'energy': 0.834,
#   'key': 8,
#   'loudness': -2.996,
#   'mode': 1,
#   'speechiness': 0.0716,
#   'acousticness': 0.61,
#   'instrumentalness': 0,
#   'liveness': 0.0518,
#   'valence': 0.896,
#   'tempo': 104.892,
#   'type': 'audio_features',
#   'id': '67OtXekkKRL5DZX3zEpdnA',
#   'uri': 'spotify:track:67OtXekkKRL5DZX3zEpdnA',
#   'track_href': 'https://api.spotify.com/v1/tracks/67OtXekkKRL5DZX3zEpdnA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/67OtXekkKRL5DZX3zEpdnA',
#   'duration_ms': 146987,
#   'time_signature': 4},
#  {'danceability': 0.719,
#   'energy': 0.499,
#   'key': 7,
#   'loudness': -16.829,
#   'mode': 1,
#   'speechiness': 0.214,
#   'acousticness': 0.801,
#   'instrumentalness': 0.0131,
#   'liveness': 0.0855,
#   'valence': 0.289,
#   'tempo': 120.011,
#   'type': 'audio_features',
#   'id': '2JqNypbkqPNtCLBeuUqmnm',
#   'uri': 'spotify:track:2JqNypbkqPNtCLBeuUqmnm',
#   'track_href': 'https://api.spotify.com/v1/tracks/2JqNypbkqPNtCLBeuUqmnm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2JqNypbkqPNtCLBeuUqmnm',
#   'duration_ms': 136773,
#   'time_signature': 4},
#  {'danceability': 0.529,
#   'energy': 0.89,
#   'key': 0,
#   'loudness': -6.104,
#   'mode': 0,
#   'speechiness': 0.0388,
#   'acousticness': 0.0185,
#   'instrumentalness': 0.00112,
#   'liveness': 0.341,
#   'valence': 0.875,
#   'tempo': 96.731,
#   'type': 'audio_features',
#   'id': '0oTGa77jJ1H5joTG5SvxFj',
#   'uri': 'spotify:track:0oTGa77jJ1H5joTG5SvxFj',
#   'track_href': 'https://api.spotify.com/v1/tracks/0oTGa77jJ1H5joTG5SvxFj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0oTGa77jJ1H5joTG5SvxFj',
#   'duration_ms': 176067,
#   'time_signature': 4},
#  {'danceability': 0.415,
#   'energy': 0.273,
#   'key': 2,
#   'loudness': -19.121,
#   'mode': 0,
#   'speechiness': 0.0349,
#   'acousticness': 0.738,
#   'instrumentalness': 0.834,
#   'liveness': 0.115,
#   'valence': 0.308,
#   'tempo': 84.562,
#   'type': 'audio_features',
#   'id': '2zYjM0an9pTfxCDRimSRia',
#   'uri': 'spotify:track:2zYjM0an9pTfxCDRimSRia',
#   'track_href': 'https://api.spotify.com/v1/tracks/2zYjM0an9pTfxCDRimSRia',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2zYjM0an9pTfxCDRimSRia',
#   'duration_ms': 292960,
#   'time_signature': 4},
#  {'danceability': 0.305,
#   'energy': 0.745,
#   'key': 10,
#   'loudness': -5.675,
#   'mode': 1,
#   'speechiness': 0.0314,
#   'acousticness': 0.0012,
#   'instrumentalness': 0,
#   'liveness': 0.109,
#   'valence': 0.427,
#   'tempo': 151.26,
#   'type': 'audio_features',
#   'id': '2zIA3HbVOu5LiOk6akCtLd',
#   'uri': 'spotify:track:2zIA3HbVOu5LiOk6akCtLd',
#   'track_href': 'https://api.spotify.com/v1/tracks/2zIA3HbVOu5LiOk6akCtLd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2zIA3HbVOu5LiOk6akCtLd',
#   'duration_ms': 307533,
#   'time_signature': 4},
#  {'danceability': 0.18,
#   'energy': 0.126,
#   'key': 8,
#   'loudness': -17.595,
#   'mode': 1,
#   'speechiness': 0.0379,
#   'acousticness': 0.852,
#   'instrumentalness': 0.905,
#   'liveness': 0.0873,
#   'valence': 0.0388,
#   'tempo': 71.598,
#   'type': 'audio_features',
#   'id': '41OlawxqIkhewGZe2NR9Qk',
#   'uri': 'spotify:track:41OlawxqIkhewGZe2NR9Qk',
#   'track_href': 'https://api.spotify.com/v1/tracks/41OlawxqIkhewGZe2NR9Qk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/41OlawxqIkhewGZe2NR9Qk',
#   'duration_ms': 239760,
#   'time_signature': 4},
#  {'danceability': 0.787,
#   'energy': 0.811,
#   'key': 0,
#   'loudness': -6.546,
#   'mode': 1,
#   'speechiness': 0.0592,
#   'acousticness': 0.195,
#   'instrumentalness': 4.63e-05,
#   'liveness': 0.372,
#   'valence': 0.727,
#   'tempo': 96.384,
#   'type': 'audio_features',
#   'id': '1hqSh8mzSOjritWWdpwVwy',
#   'uri': 'spotify:track:1hqSh8mzSOjritWWdpwVwy',
#   'track_href': 'https://api.spotify.com/v1/tracks/1hqSh8mzSOjritWWdpwVwy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1hqSh8mzSOjritWWdpwVwy',
#   'duration_ms': 268267,
#   'time_signature': 4},
#  {'danceability': 0.374,
#   'energy': 0.803,
#   'key': 10,
#   'loudness': -4.678,
#   'mode': 1,
#   'speechiness': 0.0424,
#   'acousticness': 0.00348,
#   'instrumentalness': 0,
#   'liveness': 0.11,
#   'valence': 0.57,
#   'tempo': 175.865,
#   'type': 'audio_features',
#   'id': '47hxi2GtzrNpg1gaq0jmnX',
#   'uri': 'spotify:track:47hxi2GtzrNpg1gaq0jmnX',
#   'track_href': 'https://api.spotify.com/v1/tracks/47hxi2GtzrNpg1gaq0jmnX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/47hxi2GtzrNpg1gaq0jmnX',
#   'duration_ms': 226733,
#   'time_signature': 4},
#  {'danceability': 0.23,
#   'energy': 0.349,
#   'key': 0,
#   'loudness': -18.46,
#   'mode': 1,
#   'speechiness': 0.0389,
#   'acousticness': 0.718,
#   'instrumentalness': 0.913,
#   'liveness': 0.536,
#   'valence': 0.425,
#   'tempo': 129.393,
#   'type': 'audio_features',
#   'id': '3uvLTz6fGzigCqqgroho25',
#   'uri': 'spotify:track:3uvLTz6fGzigCqqgroho25',
#   'track_href': 'https://api.spotify.com/v1/tracks/3uvLTz6fGzigCqqgroho25',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3uvLTz6fGzigCqqgroho25',
#   'duration_ms': 281000,
#   'time_signature': 3},
#  {'danceability': 0.472,
#   'energy': 0.695,
#   'key': 10,
#   'loudness': -5.008,
#   'mode': 0,
#   'speechiness': 0.443,
#   'acousticness': 0.239,
#   'instrumentalness': 0,
#   'liveness': 0.0942,
#   'valence': 0.351,
#   'tempo': 73.031,
#   'type': 'audio_features',
#   'id': '1CGP5ioAXECjvTJdMTvX0O',
#   'uri': 'spotify:track:1CGP5ioAXECjvTJdMTvX0O',
#   'track_href': 'https://api.spotify.com/v1/tracks/1CGP5ioAXECjvTJdMTvX0O',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1CGP5ioAXECjvTJdMTvX0O',
#   'duration_ms': 250467,
#   'time_signature': 3},
#  {'danceability': 0.485,
#   'energy': 0.72,
#   'key': 6,
#   'loudness': -5.991,
#   'mode': 1,
#   'speechiness': 0.127,
#   'acousticness': 0.0123,
#   'instrumentalness': 0,
#   'liveness': 0.0546,
#   'valence': 0.0471,
#   'tempo': 207.982,
#   'type': 'audio_features',
#   'id': '1j6kDJttn6wbVyMaM42Nxm',
#   'uri': 'spotify:track:1j6kDJttn6wbVyMaM42Nxm',
#   'track_href': 'https://api.spotify.com/v1/tracks/1j6kDJttn6wbVyMaM42Nxm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1j6kDJttn6wbVyMaM42Nxm',
#   'duration_ms': 126960,
#   'time_signature': 4},
#  {'danceability': 0.527,
#   'energy': 0.851,
#   'key': 5,
#   'loudness': -4.11,
#   'mode': 1,
#   'speechiness': 0.033,
#   'acousticness': 9.85e-06,
#   'instrumentalness': 0.936,
#   'liveness': 0.306,
#   'valence': 0.402,
#   'tempo': 114.981,
#   'type': 'audio_features',
#   'id': '7nBCUygrEGaU0Hvr9u6ntW',
#   'uri': 'spotify:track:7nBCUygrEGaU0Hvr9u6ntW',
#   'track_href': 'https://api.spotify.com/v1/tracks/7nBCUygrEGaU0Hvr9u6ntW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7nBCUygrEGaU0Hvr9u6ntW',
#   'duration_ms': 123853,
#   'time_signature': 4},
#  {'danceability': 0.558,
#   'energy': 0.808,
#   'key': 9,
#   'loudness': -4.284,
#   'mode': 1,
#   'speechiness': 0.367,
#   'acousticness': 0.384,
#   'instrumentalness': 0,
#   'liveness': 0.26,
#   'valence': 0.63,
#   'tempo': 157.418,
#   'type': 'audio_features',
#   'id': '7dK9JJXrbDFc29n23BqUso',
#   'uri': 'spotify:track:7dK9JJXrbDFc29n23BqUso',
#   'track_href': 'https://api.spotify.com/v1/tracks/7dK9JJXrbDFc29n23BqUso',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7dK9JJXrbDFc29n23BqUso',
#   'duration_ms': 222781,
#   'time_signature': 4},
#  {'danceability': 0.355,
#   'energy': 0.243,
#   'key': 0,
#   'loudness': -17.724,
#   'mode': 1,
#   'speechiness': 0.0375,
#   'acousticness': 0.806,
#   'instrumentalness': 0.907,
#   'liveness': 0.192,
#   'valence': 0.195,
#   'tempo': 128.459,
#   'type': 'audio_features',
#   'id': '53Y16ElHFkfFhzl3aIXXCF',
#   'uri': 'spotify:track:53Y16ElHFkfFhzl3aIXXCF',
#   'track_href': 'https://api.spotify.com/v1/tracks/53Y16ElHFkfFhzl3aIXXCF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/53Y16ElHFkfFhzl3aIXXCF',
#   'duration_ms': 310800,
#   'time_signature': 4},
#  {'danceability': 0.63,
#   'energy': 0.628,
#   'key': 2,
#   'loudness': -4.016,
#   'mode': 1,
#   'speechiness': 0.327,
#   'acousticness': 0.0515,
#   'instrumentalness': 0,
#   'liveness': 0.091,
#   'valence': 0.266,
#   'tempo': 121.307,
#   'type': 'audio_features',
#   'id': '7sLDnUauivS2vN6Z9EfUJT',
#   'uri': 'spotify:track:7sLDnUauivS2vN6Z9EfUJT',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sLDnUauivS2vN6Z9EfUJT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sLDnUauivS2vN6Z9EfUJT',
#   'duration_ms': 282667,
#   'time_signature': 5},
#  {'danceability': 0.557,
#   'energy': 0.813,
#   'key': 7,
#   'loudness': -5.745,
#   'mode': 1,
#   'speechiness': 0.034,
#   'acousticness': 0.00758,
#   'instrumentalness': 0.247,
#   'liveness': 0.112,
#   'valence': 0.174,
#   'tempo': 115.452,
#   'type': 'audio_features',
#   'id': '17k0ItD5xU09ORtsUrb2dO',
#   'uri': 'spotify:track:17k0ItD5xU09ORtsUrb2dO',
#   'track_href': 'https://api.spotify.com/v1/tracks/17k0ItD5xU09ORtsUrb2dO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/17k0ItD5xU09ORtsUrb2dO',
#   'duration_ms': 210427,
#   'time_signature': 4},
#  {'danceability': 0.454,
#   'energy': 0.503,
#   'key': 0,
#   'loudness': -7.61,
#   'mode': 1,
#   'speechiness': 0.0265,
#   'acousticness': 0.376,
#   'instrumentalness': 0.0076,
#   'liveness': 0.242,
#   'valence': 0.401,
#   'tempo': 150.999,
#   'type': 'audio_features',
#   'id': '5v9e0mJg74D7cFfYxKDJH0',
#   'uri': 'spotify:track:5v9e0mJg74D7cFfYxKDJH0',
#   'track_href': 'https://api.spotify.com/v1/tracks/5v9e0mJg74D7cFfYxKDJH0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5v9e0mJg74D7cFfYxKDJH0',
#   'duration_ms': 245693,
#   'time_signature': 3},
#  {'danceability': 0.158,
#   'energy': 0.154,
#   'key': 7,
#   'loudness': -17.596,
#   'mode': 1,
#   'speechiness': 0.0384,
#   'acousticness': 0.953,
#   'instrumentalness': 0.658,
#   'liveness': 0.12,
#   'valence': 0.166,
#   'tempo': 74.988,
#   'type': 'audio_features',
#   'id': '4WIyNmRe7htCNYwMOpF18p',
#   'uri': 'spotify:track:4WIyNmRe7htCNYwMOpF18p',
#   'track_href': 'https://api.spotify.com/v1/tracks/4WIyNmRe7htCNYwMOpF18p',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4WIyNmRe7htCNYwMOpF18p',
#   'duration_ms': 312933,
#   'time_signature': 4},
#  {'danceability': 0.724,
#   'energy': 0.798,
#   'key': 11,
#   'loudness': -4.671,
#   'mode': 0,
#   'speechiness': 0.241,
#   'acousticness': 0.238,
#   'instrumentalness': 0,
#   'liveness': 0.148,
#   'valence': 0.902,
#   'tempo': 103.232,
#   'type': 'audio_features',
#   'id': '5f8KBsReTKtWQl9vrWhrtg',
#   'uri': 'spotify:track:5f8KBsReTKtWQl9vrWhrtg',
#   'track_href': 'https://api.spotify.com/v1/tracks/5f8KBsReTKtWQl9vrWhrtg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5f8KBsReTKtWQl9vrWhrtg',
#   'duration_ms': 149093,
#   'time_signature': 4}]

# %% [markdown]
# ### Creating dataframe from returned audiofeatures

# %%
df1=pd.DataFrame(audio_feat_1)

df1=df1[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df1
# Out:
#     danceability  energy  loudness  speechiness  acousticness
# 0          0.766  0.8050    -2.771       0.0443       0.70500  \
# 1          0.828  0.5920    -7.080       0.0501       0.67800
# 2          0.234  0.8280    -5.048       0.0412       0.00119
# 3          0.505  0.4630   -10.653       0.1240       0.51800
# 4          0.167  0.0581   -21.249       0.0356       0.96900
# ..           ...     ...       ...          ...           ...
# 95         0.630  0.6280    -4.016       0.3270       0.05150
# 96         0.557  0.8130    -5.745       0.0340       0.00758
# 97         0.454  0.5030    -7.610       0.0265       0.37600
# 98         0.158  0.1540   -17.596       0.0384       0.95300
# 99         0.724  0.7980    -4.671       0.2410       0.23800
#
#     instrumentalness  liveness  valence    tempo                      id
# 0           0.000000    0.0928   0.9670  114.195  4VZ0UOLwnTnQSLZJme5lyQ  \
# 1           0.000107    0.1870   0.7950  101.646  5dFwDUe9DMl28LpROkhZu4
# 2           0.000000    0.1580   0.4040  168.073  1L4ca7Ti3S795YrBdTzE4T
# 3           0.000016    0.7150   0.6590  105.661  5ZdziocLu1aGzSRixpW3rr
# 4           0.363000    0.0873   0.0733   75.979  6lIyXleBCaWzOn9Ltjg6E5
# ..               ...       ...      ...      ...                     ...
# 95          0.000000    0.0910   0.2660  121.307  7sLDnUauivS2vN6Z9EfUJT
# 96          0.247000    0.1120   0.1740  115.452  17k0ItD5xU09ORtsUrb2dO
# 97          0.007600    0.2420   0.4010  150.999  5v9e0mJg74D7cFfYxKDJH0
# 98          0.658000    0.1200   0.1660   74.988  4WIyNmRe7htCNYwMOpF18p
# 99          0.000000    0.1480   0.9020  103.232  5f8KBsReTKtWQl9vrWhrtg
#
#     duration_ms
# 0        168653
# 1        436760
# 2        265520
# 3        214924
# 4        294133
# ..          ...
# 95       282667
# 96       210427
# 97       245693
# 98       312933
# 99       149093
#
# [100 rows x 11 columns]

# %%
df1.duplicated().sum()
# Out:
# 0
